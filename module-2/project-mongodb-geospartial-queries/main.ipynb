# %%
from pymongo import MongoClient
import json
import pandas as pd
import numpy as np
from bson import json_util


client = MongoClient('mongodb://localhost:27017/')
db = client.companies

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'companies')

# %%
# Primero quiero obtener un listado de todas las empresas que han quebrado para evitar esas localizaciones
# de esta manera pretendo establecer criterios a la inversa.

companies_broken = db.companies.find({'$and':[
                                      {'deadpooled_year':{'$not':{'$eq':None}}}, 
                                      {'offices.latitude':{'$exists':True}},
                                      {'offices.longitude':{'$exists':True}}, 
                                      {'offices.latitude':{'$ne':None}},
                                      {'offices.longitude':{'$ne':None}}]})

# %%
companies_broken = pd.DataFrame(list(companies_broken))
companies_broken.head(2)
# Out:
#                         _id  \
# 0  52cdef7c4bab8bd675297d8b
# 1  52cdef7c4bab8bd675297d8a
#
#                                          acquisition acquisitions  \
# 0                                               None           []
# 1  {'source_description': ' Viggle Tries to Bulk ...           []
#
#            alias_list                     blog_feed_url  \
# 0  Zoho ManageEngine
# 1                      http://digitalquarters.net/feed/
#
#                       blog_url category_code  \
# 0                                 enterprise
# 1  http://digitalquarters.net/           web
#
#                                         competitions           created_at  \
# 0                                                 []  2007-05-25 19:24:22
# 1  [{'competitor': {'name': 'Wikia', 'permalink':...  2007-05-25 06:51:27
#
#                                 crunchbase_url  ...  phone_number  \
# 0  http://www.crunchbase.com/company/adventnet  ...  925-924-9500
# 1   http://www.crunchbase.com/company/wetpaint  ...  206.859.6300
#
#                                             products  \
# 0                                                 []
# 1  [{'name': 'Wikison Wetpaint', 'permalink': 'we...
#
#                                        providerships  \
# 0  [{'provider': {'name': 'A Small Orange', 'perm...
# 1                                                 []
#
#                                        relationships  \
# 0  [{'title': 'CEO and Co-Founder', 'is_past': Tr...
# 1  [{'title': 'Co-Founder and VP, Social and Audi...
#
#                                          screenshots  \
# 0  [{'attribution': None, 'available_sizes': [[[1...
# 1  [{'attribution': None, 'available_sizes': [[[1...
#
#                                             tag_list total_money_raised  \
# 0                                                                    $0
# 1  wiki, seattle, elowitz, media-industry, media-...             $39.8M
#
#    twitter_username                    updated_at  video_embeds
# 0      manageengine  Wed Oct 31 18:26:09 UTC 2012            []
# 1   BachelrWetpaint  Sun Dec 08 07:15:44 UTC 2013            []
#
# [2 rows x 42 columns]

# %%
companies_broken.set_index('_id', inplace=True)
companies_broken.head(2)
# Out:
#                                                                 acquisition  \
# _id
# 52cdef7c4bab8bd675297d8b                                               None
# 52cdef7c4bab8bd675297d8a  {'source_description': ' Viggle Tries to Bulk ...
#
#                          acquisitions          alias_list  \
# _id
# 52cdef7c4bab8bd675297d8b           []  Zoho ManageEngine
# 52cdef7c4bab8bd675297d8a           []
#
#                                              blog_feed_url  \
# _id
# 52cdef7c4bab8bd675297d8b
# 52cdef7c4bab8bd675297d8a  http://digitalquarters.net/feed/
#
#                                              blog_url category_code  \
# _id
# 52cdef7c4bab8bd675297d8b                                 enterprise
# 52cdef7c4bab8bd675297d8a  http://digitalquarters.net/           web
#
#                                                                competitions  \
# _id
# 52cdef7c4bab8bd675297d8b                                                 []
# 52cdef7c4bab8bd675297d8a  [{'competitor': {'name': 'Wikia', 'permalink':...
#
#                                    created_at  \
# _id
# 52cdef7c4bab8bd675297d8b  2007-05-25 19:24:22
# 52cdef7c4bab8bd675297d8a  2007-05-25 06:51:27
#
#                                                        crunchbase_url  \
# _id
# 52cdef7c4bab8bd675297d8b  http://www.crunchbase.com/company/adventnet
# 52cdef7c4bab8bd675297d8a   http://www.crunchbase.com/company/wetpaint
#
#                           deadpooled_day  ...  phone_number  \
# _id                                       ...
# 52cdef7c4bab8bd675297d8b             NaN  ...  925-924-9500
# 52cdef7c4bab8bd675297d8a             NaN  ...  206.859.6300
#
#                                                                    products  \
# _id
# 52cdef7c4bab8bd675297d8b                                                 []
# 52cdef7c4bab8bd675297d8a  [{'name': 'Wikison Wetpaint', 'permalink': 'we...
#
#                                                               providerships  \
# _id
# 52cdef7c4bab8bd675297d8b  [{'provider': {'name': 'A Small Orange', 'perm...
# 52cdef7c4bab8bd675297d8a                                                 []
#
#                                                               relationships  \
# _id
# 52cdef7c4bab8bd675297d8b  [{'title': 'CEO and Co-Founder', 'is_past': Tr...
# 52cdef7c4bab8bd675297d8a  [{'title': 'Co-Founder and VP, Social and Audi...
#
#                                                                 screenshots  \
# _id
# 52cdef7c4bab8bd675297d8b  [{'attribution': None, 'available_sizes': [[[1...
# 52cdef7c4bab8bd675297d8a  [{'attribution': None, 'available_sizes': [[[1...
#
#                                                                    tag_list  \
# _id
# 52cdef7c4bab8bd675297d8b
# 52cdef7c4bab8bd675297d8a  wiki, seattle, elowitz, media-industry, media-...
#
#                           total_money_raised  twitter_username  \
# _id
# 52cdef7c4bab8bd675297d8b                  $0      manageengine
# 52cdef7c4bab8bd675297d8a              $39.8M   BachelrWetpaint
#
#                                             updated_at video_embeds
# _id
# 52cdef7c4bab8bd675297d8b  Wed Oct 31 18:26:09 UTC 2012           []
# 52cdef7c4bab8bd675297d8a  Sun Dec 08 07:15:44 UTC 2013           []
#
# [2 rows x 41 columns]

# %%
# Para poder ver el número de cada columna que quiero eliminar, he recurrido a un loop for con un enumerate
# de esta forma obtengo el número de cada columna para así eliminar las que no me interesan en el siguiente paso
'''
for x,y in enumerate (companies_broken.columns):
    print (x, " - ", y)
'''
#Como ocupa mucho, una vez cumplida su función lo dejo como anotación para que no ocupe mucho
# Out:
# '\nfor x,y in enumerate (companies_broken.columns):\n    print (x, " - ", y)\n'

# %%
#Eliminamos las columnas que no nos son de utilidad

companies_broken.drop(companies_broken.columns[[0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 14, 15, 16, 17, 20, 21, 22, 24, 28, 29, 30, 31, 32, 33, 34, 35, 38, 39, 40
]], axis=1, inplace=True)

companies_broken.head(2)
# Out:
#                          category_code  deadpooled_year  \
# _id
# 52cdef7c4bab8bd675297d8b    enterprise                2
# 52cdef7c4bab8bd675297d8a           web                1
#
#                                           description  founded_year  \
# _id
# 52cdef7c4bab8bd675297d8b   Server Management Software        1996.0
# 52cdef7c4bab8bd675297d8a  Technology Platform Company        2005.0
#
#                                                              funding_rounds  \
# _id
# 52cdef7c4bab8bd675297d8b                                                 []
# 52cdef7c4bab8bd675297d8a  [{'source_description': '', 'raised_currency_c...
#
#                           ipo       name  number_of_employees  \
# _id
# 52cdef7c4bab8bd675297d8b  NaN  AdventNet                600.0
# 52cdef7c4bab8bd675297d8a  NaN   Wetpaint                 47.0
#
#                                                                     offices  \
# _id
# 52cdef7c4bab8bd675297d8b  [{'city': 'Pleasanton', 'address2': 'Suite 310...
# 52cdef7c4bab8bd675297d8a  [{'city': 'Seattle', 'address2': 'Suite 1100',...
#
#                                                                    tag_list  \
# _id
# 52cdef7c4bab8bd675297d8b
# 52cdef7c4bab8bd675297d8a  wiki, seattle, elowitz, media-industry, media-...
#
#                          total_money_raised
# _id
# 52cdef7c4bab8bd675297d8b                 $0
# 52cdef7c4bab8bd675297d8a             $39.8M

# %%
def getFirst(data):
    data = data['offices']

    principal = None
    if data[0]['latitude'] and data[0]['longitude']:
        principal = {
            "type":"Point",
            "coordinates":[data[0]['longitude'], data[0]['latitude']]
        }

    return {
        "totalOffices": len(data),
        "lat": data[0]['latitude'],
        "lng": data[0]['longitude'],
        "oficina_principal": principal
    }


comp_br_off = companies_broken[["offices"]].apply(getFirst, result_type="expand", axis=1)

# %%
companies_broken = pd.concat([companies_broken, comp_br_off], axis=1)
companies_broken.head(2)
# Out:
#                          category_code  deadpooled_year  \
# _id
# 52cdef7c4bab8bd675297d8b    enterprise                2
# 52cdef7c4bab8bd675297d8a           web                1
#
#                                           description  founded_year  \
# _id
# 52cdef7c4bab8bd675297d8b   Server Management Software        1996.0
# 52cdef7c4bab8bd675297d8a  Technology Platform Company        2005.0
#
#                                                              funding_rounds  \
# _id
# 52cdef7c4bab8bd675297d8b                                                 []
# 52cdef7c4bab8bd675297d8a  [{'source_description': '', 'raised_currency_c...
#
#                           ipo       name  number_of_employees  \
# _id
# 52cdef7c4bab8bd675297d8b  NaN  AdventNet                600.0
# 52cdef7c4bab8bd675297d8a  NaN   Wetpaint                 47.0
#
#                                                                     offices  \
# _id
# 52cdef7c4bab8bd675297d8b  [{'city': 'Pleasanton', 'address2': 'Suite 310...
# 52cdef7c4bab8bd675297d8a  [{'city': 'Seattle', 'address2': 'Suite 1100',...
#
#                                                                    tag_list  \
# _id
# 52cdef7c4bab8bd675297d8b
# 52cdef7c4bab8bd675297d8a  wiki, seattle, elowitz, media-industry, media-...
#
#                          total_money_raised        lat         lng  \
# _id
# 52cdef7c4bab8bd675297d8b                 $0  37.692934 -121.904945
# 52cdef7c4bab8bd675297d8a             $39.8M  47.603122 -122.333253
#
#                                                           oficina_principal  \
# _id
# 52cdef7c4bab8bd675297d8b  {'type': 'Point', 'coordinates': [-121.904945,...
# 52cdef7c4bab8bd675297d8a  {'type': 'Point', 'coordinates': [-122.333253,...
#
#                           totalOffices
# _id
# 52cdef7c4bab8bd675297d8b             1
# 52cdef7c4bab8bd675297d8a             2

# %%
# Ahora guardamos el dataframe en un json

companies_broken.to_json('./companies_broken.json', default_handler=str)

# %%
# Ahora vamos a hacer un listado con las empresas que no cumplen con nuestros requisitos para 
# tenerlas ubicadas y así poder establecer descartes

companies_dislike = db.companies.find({'$and':
                                      [{'deadpooled_year':{'$eq':None}},{'founded_year':{'$lt':2008}},
                                       {"offices.latitude":{'$exists':True}},{"offices.longitude":
                                       {'$exists':True}},{"offices.latitude":{'$ne':None}},
                                       {"offices.longitude":{'$ne':None}}]})

# %%
companies_dislike = pd.DataFrame(list(companies_dislike))
companies_dislike.head(2)
# Out:
#                         _id  \
# 0  52cdef7c4bab8bd675297d8d
# 1  52cdef7c4bab8bd675297d90
#
#                                          acquisition  \
# 0  {'source_description': 'Betaworks Acquires Dig...
# 1  {'source_description': 'http://www.techcrunch....
#
#                                         acquisitions alias_list  \
# 0  [{'source_description': '', 'company': {'name'...
# 1                                                 []       None
#
#                      blog_feed_url               blog_url category_code  \
# 0  http://blog.digg.com/?feed=rss2  http://blog.digg.com/          news
# 1                                                                   web
#
#                                         competitions  \
# 0  [{'competitor': {'name': 'Reddit', 'permalink'...
# 1  [{'competitor': {'name': 'RescueTime', 'permal...
#
#                      created_at                             crunchbase_url  \
# 0  Fri May 25 20:03:23 UTC 2007     http://www.crunchbase.com/company/digg
# 1  Fri Jun 08 12:19:51 UTC 2007  http://www.crunchbase.com/company/postini
#
#    ...    phone_number                                           products  \
# 0  ...  (415) 436-9638            [{'name': 'Digg', 'permalink': 'digg'}]
# 1  ...    888.584.3150  [{'name': 'Postini Solutions', 'permalink': 'p...
#
#                                        providerships  \
# 0  [{'provider': {'name': 'K/F Communications', '...
# 1                                                 []
#
#                                        relationships  \
# 0  [{'title': 'CEO', 'is_past': False, 'person': ...
# 1  [{'title': 'Board', 'is_past': False, 'person'...
#
#                                          screenshots  \
# 0  [{'attribution': None, 'available_sizes': [[[1...
# 1                                                 []
#
#                                             tag_list total_money_raised  \
# 0  community, social, news, bookmark, digg, techn...               $45M
# 1                                                                    $0
#
#    twitter_username                    updated_at  \
# 0              digg  Tue Nov 05 21:35:47 UTC 2013
# 1              None  Sat Aug 13 18:02:34 UTC 2011
#
#                                         video_embeds
# 0  [{'description': '<p>This video was originally...
# 1                                                 []
#
# [2 rows x 42 columns]

# %%
companies_dislike.set_index('_id', inplace=True)
companies_dislike.head(2)
# Out:
#                                                                 acquisition  \
# _id
# 52cdef7c4bab8bd675297d8d  {'source_description': 'Betaworks Acquires Dig...
# 52cdef7c4bab8bd675297d90  {'source_description': 'http://www.techcrunch....
#
#                                                                acquisitions  \
# _id
# 52cdef7c4bab8bd675297d8d  [{'source_description': '', 'company': {'name'...
# 52cdef7c4bab8bd675297d90                                                 []
#
#                          alias_list                    blog_feed_url  \
# _id
# 52cdef7c4bab8bd675297d8d             http://blog.digg.com/?feed=rss2
# 52cdef7c4bab8bd675297d90       None
#
#                                        blog_url category_code  \
# _id
# 52cdef7c4bab8bd675297d8d  http://blog.digg.com/          news
# 52cdef7c4bab8bd675297d90                                  web
#
#                                                                competitions  \
# _id
# 52cdef7c4bab8bd675297d8d  [{'competitor': {'name': 'Reddit', 'permalink'...
# 52cdef7c4bab8bd675297d90  [{'competitor': {'name': 'RescueTime', 'permal...
#
#                                             created_at  \
# _id
# 52cdef7c4bab8bd675297d8d  Fri May 25 20:03:23 UTC 2007
# 52cdef7c4bab8bd675297d90  Fri Jun 08 12:19:51 UTC 2007
#
#                                                      crunchbase_url  \
# _id
# 52cdef7c4bab8bd675297d8d     http://www.crunchbase.com/company/digg
# 52cdef7c4bab8bd675297d90  http://www.crunchbase.com/company/postini
#
#                          deadpooled_day  ...    phone_number  \
# _id                                      ...
# 52cdef7c4bab8bd675297d8d           None  ...  (415) 436-9638
# 52cdef7c4bab8bd675297d90           None  ...    888.584.3150
#
#                                                                    products  \
# _id
# 52cdef7c4bab8bd675297d8d            [{'name': 'Digg', 'permalink': 'digg'}]
# 52cdef7c4bab8bd675297d90  [{'name': 'Postini Solutions', 'permalink': 'p...
#
#                                                               providerships  \
# _id
# 52cdef7c4bab8bd675297d8d  [{'provider': {'name': 'K/F Communications', '...
# 52cdef7c4bab8bd675297d90                                                 []
#
#                                                               relationships  \
# _id
# 52cdef7c4bab8bd675297d8d  [{'title': 'CEO', 'is_past': False, 'person': ...
# 52cdef7c4bab8bd675297d90  [{'title': 'Board', 'is_past': False, 'person'...
#
#                                                                 screenshots  \
# _id
# 52cdef7c4bab8bd675297d8d  [{'attribution': None, 'available_sizes': [[[1...
# 52cdef7c4bab8bd675297d90                                                 []
#
#                                                                    tag_list  \
# _id
# 52cdef7c4bab8bd675297d8d  community, social, news, bookmark, digg, techn...
# 52cdef7c4bab8bd675297d90
#
#                           total_money_raised  twitter_username  \
# _id
# 52cdef7c4bab8bd675297d8d                $45M              digg
# 52cdef7c4bab8bd675297d90                  $0              None
#
#                                             updated_at  \
# _id
# 52cdef7c4bab8bd675297d8d  Tue Nov 05 21:35:47 UTC 2013
# 52cdef7c4bab8bd675297d90  Sat Aug 13 18:02:34 UTC 2011
#
#                                                                video_embeds
# _id
# 52cdef7c4bab8bd675297d8d  [{'description': '<p>This video was originally...
# 52cdef7c4bab8bd675297d90                                                 []
#
# [2 rows x 41 columns]

# %%
#Eliminamos las columnas que no nos son de utilidad

companies_dislike.drop(companies_dislike.columns[[0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 14, 15, 16, 17, 20, 21, 22, 24, 28, 29, 30, 31, 32, 33, 34, 35, 38, 39, 40
]], axis=1, inplace=True)

companies_dislike.head(2)
# Out:
#                          category_code deadpooled_year  \
# _id
# 52cdef7c4bab8bd675297d8d          news            None
# 52cdef7c4bab8bd675297d90           web            None
#
#                                                  description  founded_year  \
# _id
# 52cdef7c4bab8bd675297d8d  user driven social content website          2004
# 52cdef7c4bab8bd675297d90                                None          1999
#
#                                                              funding_rounds  \
# _id
# 52cdef7c4bab8bd675297d8d  [{'source_description': '', 'raised_currency_c...
# 52cdef7c4bab8bd675297d90                                                 []
#
#                            ipo     name  number_of_employees  \
# _id
# 52cdef7c4bab8bd675297d8d  None     Digg                 60.0
# 52cdef7c4bab8bd675297d90  None  Postini                  NaN
#
#                                                                     offices  \
# _id
# 52cdef7c4bab8bd675297d8d  [{'city': 'San Francisco', 'address2': '', 'st...
# 52cdef7c4bab8bd675297d90  [{'city': 'San Carlos', 'address2': None, 'sta...
#
#                                                                    tag_list  \
# _id
# 52cdef7c4bab8bd675297d8d  community, social, news, bookmark, digg, techn...
# 52cdef7c4bab8bd675297d90
#
#                          total_money_raised
# _id
# 52cdef7c4bab8bd675297d8d               $45M
# 52cdef7c4bab8bd675297d90                 $0

# %%
comp_dislike_off = companies_dislike[["offices"]].apply(getFirst, result_type="expand", axis=1)

# %%
companies_dislike = pd.concat([companies_dislike, comp_dislike_off], axis=1)
companies_dislike.head(2)
# Out:
#                          category_code deadpooled_year  \
# _id
# 52cdef7c4bab8bd675297d8d          news            None
# 52cdef7c4bab8bd675297d90           web            None
#
#                                                  description  founded_year  \
# _id
# 52cdef7c4bab8bd675297d8d  user driven social content website          2004
# 52cdef7c4bab8bd675297d90                                None          1999
#
#                                                              funding_rounds  \
# _id
# 52cdef7c4bab8bd675297d8d  [{'source_description': '', 'raised_currency_c...
# 52cdef7c4bab8bd675297d90                                                 []
#
#                            ipo     name  number_of_employees  \
# _id
# 52cdef7c4bab8bd675297d8d  None     Digg                 60.0
# 52cdef7c4bab8bd675297d90  None  Postini                  NaN
#
#                                                                     offices  \
# _id
# 52cdef7c4bab8bd675297d8d  [{'city': 'San Francisco', 'address2': '', 'st...
# 52cdef7c4bab8bd675297d90  [{'city': 'San Carlos', 'address2': None, 'sta...
#
#                                                                    tag_list  \
# _id
# 52cdef7c4bab8bd675297d8d  community, social, news, bookmark, digg, techn...
# 52cdef7c4bab8bd675297d90
#
#                          total_money_raised        lat         lng  \
# _id
# 52cdef7c4bab8bd675297d8d               $45M  37.764726 -122.394523
# 52cdef7c4bab8bd675297d90                 $0  37.506885 -122.247573
#
#                                                           oficina_principal  \
# _id
# 52cdef7c4bab8bd675297d8d  {'type': 'Point', 'coordinates': [-122.394523,...
# 52cdef7c4bab8bd675297d90  {'type': 'Point', 'coordinates': [-122.247573,...
#
#                           totalOffices
# _id
# 52cdef7c4bab8bd675297d8d             1
# 52cdef7c4bab8bd675297d90             1

# %%
# Ahora guardamos el dataframe en un json

companies_dislike.to_json('./companies_dislike.json', default_handler=str)

# %%
#Aquí hacemos un filtro de las empresas que pueden encajar con nuestros requisitos


filtered_companies = db.companies.find({'$and': 
                                        [{'deadpooled_year':{'$eq':None}}, {'founded_year':{'$gte':2008}},
                                         {"offices.latitude":{'$exists':True}},{"offices.longitude":{'$exists':True}},
                                         {"offices.latitude":{'$ne':None}},{"offices.longitude":{'$ne':None}}]})

# %%
filtered_companies = pd.DataFrame(list(filtered_companies))
filtered_companies.head(2)
# Out:
#                         _id acquisition acquisitions alias_list blog_feed_url  \
# 0  52cdef7c4bab8bd675297e30        None           []       None
# 1  52cdef7c4bab8bd675297ea7        None           []
#
#                   blog_url category_code  \
# 0  http://goingon.com/blog      software
# 1                                    web
#
#                                         competitions  \
# 0  [{'competitor': {'name': 'Ning by Glam Media',...
# 1  [{'competitor': {'name': 'Club Penguin', 'perm...
#
#                      created_at                              crunchbase_url  \
# 0  Fri Jul 20 04:55:26 UTC 2007   http://www.crunchbase.com/company/goingon
# 1  Tue Aug 07 05:47:56 UTC 2007  http://www.crunchbase.com/company/mokitown
#
#    ...  phone_number                                           products  \
# 0  ...  415-200-4606  [{'name': 'GoingOn', 'permalink': 'goingon'}, ...
# 1  ...                  [{'name': 'Mokitown', 'permalink': 'mokitown'}]
#
#   providerships                                      relationships  \
# 0            []  [{'title': 'CEO', 'is_past': False, 'person': ...
# 1            []                                                 []
#
#                                          screenshots  \
# 0                                                 []
# 1  [{'attribution': None, 'available_sizes': [[[1...
#
#                                             tag_list total_money_raised  \
# 0  socialnetworking, enterprise, social-media, so...              $8.5M
# 1                 mokitown, virtualworld, crunchbase                 $0
#
#    twitter_username                    updated_at  video_embeds
# 0   GoingOn_Network  Thu Apr 04 09:03:17 UTC 2013            []
# 1                    Tue Mar 19 01:07:12 UTC 2013            []
#
# [2 rows x 42 columns]

# %%
filtered_companies.set_index('_id', inplace=True)
filtered_companies.head(2)
# Out:
#                          acquisition acquisitions alias_list blog_feed_url  \
# _id
# 52cdef7c4bab8bd675297e30        None           []       None
# 52cdef7c4bab8bd675297ea7        None           []
#
#                                          blog_url category_code  \
# _id
# 52cdef7c4bab8bd675297e30  http://goingon.com/blog      software
# 52cdef7c4bab8bd675297ea7                                    web
#
#                                                                competitions  \
# _id
# 52cdef7c4bab8bd675297e30  [{'competitor': {'name': 'Ning by Glam Media',...
# 52cdef7c4bab8bd675297ea7  [{'competitor': {'name': 'Club Penguin', 'perm...
#
#                                             created_at  \
# _id
# 52cdef7c4bab8bd675297e30  Fri Jul 20 04:55:26 UTC 2007
# 52cdef7c4bab8bd675297ea7  Tue Aug 07 05:47:56 UTC 2007
#
#                                                       crunchbase_url  \
# _id
# 52cdef7c4bab8bd675297e30   http://www.crunchbase.com/company/goingon
# 52cdef7c4bab8bd675297ea7  http://www.crunchbase.com/company/mokitown
#
#                          deadpooled_day  ...  phone_number  \
# _id                                      ...
# 52cdef7c4bab8bd675297e30           None  ...  415-200-4606
# 52cdef7c4bab8bd675297ea7           None  ...
#
#                                                                    products  \
# _id
# 52cdef7c4bab8bd675297e30  [{'name': 'GoingOn', 'permalink': 'goingon'}, ...
# 52cdef7c4bab8bd675297ea7    [{'name': 'Mokitown', 'permalink': 'mokitown'}]
#
#                          providerships  \
# _id
# 52cdef7c4bab8bd675297e30            []
# 52cdef7c4bab8bd675297ea7            []
#
#                                                               relationships  \
# _id
# 52cdef7c4bab8bd675297e30  [{'title': 'CEO', 'is_past': False, 'person': ...
# 52cdef7c4bab8bd675297ea7                                                 []
#
#                                                                 screenshots  \
# _id
# 52cdef7c4bab8bd675297e30                                                 []
# 52cdef7c4bab8bd675297ea7  [{'attribution': None, 'available_sizes': [[[1...
#
#                                                                    tag_list  \
# _id
# 52cdef7c4bab8bd675297e30  socialnetworking, enterprise, social-media, so...
# 52cdef7c4bab8bd675297ea7                 mokitown, virtualworld, crunchbase
#
#                           total_money_raised  twitter_username  \
# _id
# 52cdef7c4bab8bd675297e30               $8.5M   GoingOn_Network
# 52cdef7c4bab8bd675297ea7                  $0
#
#                                             updated_at video_embeds
# _id
# 52cdef7c4bab8bd675297e30  Thu Apr 04 09:03:17 UTC 2013           []
# 52cdef7c4bab8bd675297ea7  Tue Mar 19 01:07:12 UTC 2013           []
#
# [2 rows x 41 columns]

# %%
#Eliminamos las columnas que no nos son de utilidad

filtered_companies.drop(filtered_companies.columns[[0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 14, 15, 16, 17, 20, 21, 22, 24, 28, 29, 30, 31, 32, 33, 34, 35, 38, 39, 40
]], axis=1, inplace=True)

filtered_companies.head(2)
# Out:
#                          category_code deadpooled_year  \
# _id
# 52cdef7c4bab8bd675297e30      software            None
# 52cdef7c4bab8bd675297ea7           web            None
#
#                                         description  founded_year  \
# _id
# 52cdef7c4bab8bd675297e30  Private Academic Networks          2008
# 52cdef7c4bab8bd675297ea7                                     2011
#
#                                                              funding_rounds  \
# _id
# 52cdef7c4bab8bd675297e30  [{'source_description': '', 'raised_currency_c...
# 52cdef7c4bab8bd675297ea7                                                 []
#
#                            ipo      name  number_of_employees  \
# _id
# 52cdef7c4bab8bd675297e30  None   GoingOn                 40.0
# 52cdef7c4bab8bd675297ea7  None  Mokitown                  NaN
#
#                                                                     offices  \
# _id
# 52cdef7c4bab8bd675297e30  [{'city': 'San Francisco', 'address2': '12th F...
# 52cdef7c4bab8bd675297ea7  [{'city': None, 'address2': None, 'state_code'...
#
#                                                                    tag_list  \
# _id
# 52cdef7c4bab8bd675297e30  socialnetworking, enterprise, social-media, so...
# 52cdef7c4bab8bd675297ea7                 mokitown, virtualworld, crunchbase
#
#                          total_money_raised
# _id
# 52cdef7c4bab8bd675297e30              $8.5M
# 52cdef7c4bab8bd675297ea7                 $0

# %%
fil_comp_off = filtered_companies[["offices"]].apply(getFirst, result_type="expand", axis=1)

# %%
filtered_companies = pd.concat([filtered_companies, fil_comp_off], axis=1)
filtered_companies.head(2)
# Out:
#                          category_code deadpooled_year  \
# _id
# 52cdef7c4bab8bd675297e30      software            None
# 52cdef7c4bab8bd675297ea7           web            None
#
#                                         description  founded_year  \
# _id
# 52cdef7c4bab8bd675297e30  Private Academic Networks          2008
# 52cdef7c4bab8bd675297ea7                                     2011
#
#                                                              funding_rounds  \
# _id
# 52cdef7c4bab8bd675297e30  [{'source_description': '', 'raised_currency_c...
# 52cdef7c4bab8bd675297ea7                                                 []
#
#                            ipo      name  number_of_employees  \
# _id
# 52cdef7c4bab8bd675297e30  None   GoingOn                 40.0
# 52cdef7c4bab8bd675297ea7  None  Mokitown                  NaN
#
#                                                                     offices  \
# _id
# 52cdef7c4bab8bd675297e30  [{'city': 'San Francisco', 'address2': '12th F...
# 52cdef7c4bab8bd675297ea7  [{'city': None, 'address2': None, 'state_code'...
#
#                                                                    tag_list  \
# _id
# 52cdef7c4bab8bd675297e30  socialnetworking, enterprise, social-media, so...
# 52cdef7c4bab8bd675297ea7                 mokitown, virtualworld, crunchbase
#
#                          total_money_raised        lat         lng  \
# _id
# 52cdef7c4bab8bd675297e30              $8.5M  37.782263 -122.392142
# 52cdef7c4bab8bd675297ea7                 $0  37.090240  -95.712891
#
#                                                           oficina_principal  \
# _id
# 52cdef7c4bab8bd675297e30  {'type': 'Point', 'coordinates': [-122.392142,...
# 52cdef7c4bab8bd675297ea7  {'type': 'Point', 'coordinates': [-95.712891, ...
#
#                           totalOffices
# _id
# 52cdef7c4bab8bd675297e30             1
# 52cdef7c4bab8bd675297ea7             1

# %%
filtered_companies.to_json('./filtered_companies.json', default_handler=str)
