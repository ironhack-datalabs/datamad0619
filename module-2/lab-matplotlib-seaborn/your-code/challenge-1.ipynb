# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
with_index = plt.figure()

plt.subplot(121)
plt.plot(x, y, color='g', lw=2, ls='solid')
plt.title('x, y')

plt.subplot(122)
plt.plot(x, z, color='g', lw=2, ls='-.')
plt.title('x, z')

with_index.subplots_adjust(wspace=0.4)

# %%
fig, (ax[0], ax[1]) = plt.subplots(1,2)

ax[0].plot(x, y, color='r', lw=2, ls='--')
ax[0].set_title('x, y')
ax[1].plot(x, z, color='r', lw=2, ls=':')
ax[1].set_title('x, z')

fig.subplots_adjust(wspace=0.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5db5d42bf8c4> in <module>
# ----> 1 fig, (ax[0], ax[1]) = plt.subplots(1,2)
#       2
#       3 ax[0].plot(x, y, color='r', lw=2, ls='--')
#       4 ax[0].set_title('x, y')
#       5 ax[1].plot(x, z, color='r', lw=2, ls=':')
#
# NameError: name 'ax' is not defined

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
fig, (ax[0], ax[1]) = plt.subplots(1,2, figsize=(20,10))

ax[0].plot(x, y, color='c', lw=5, ls='dashed')
ax[0].set_title('x, y')
ax[1].plot(x, z, color='tab:orange', lw=5, ls='dotted')
ax[1].set_title('x, z')

fig.subplots_adjust(wspace=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3e69ca65dc45> in <module>
# ----> 1 fig, (ax[0], ax[1]) = plt.subplots(1,2, figsize=(20,10))
#       2
#       3 ax[0].plot(x, y, color='c', lw=5, ls='dashed')
#       4 ax[0].set_title('x, y')
#       5 ax[1].plot(x, z, color='tab:orange', lw=5, ls='dotted')
#
# NameError: name 'ax' is not defined

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
fig, (ax[0], ax[1]) = plt.subplots(1,2, figsize=(20,10))

ax[0].plot(x, y, color='#0f5f5f', lw=5, ls='-.')
ax[0].set_title('x, y')
ax[0].set(xlabel='X axis', ylabel='Y axis')
ax[1].plot(x, z, color='xkcd:sky blue', lw=5, ls='solid')
ax[1].set_title('x, z')
ax[1].set(xlabel='X axis', ylabel='Y axis')

fig.subplots_adjust(wspace=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b8762726f04d> in <module>
# ----> 1 fig, (ax[0], ax[1]) = plt.subplots(1,2, figsize=(20,10))
#       2
#       3 ax[0].plot(x, y, color='#0f5f5f', lw=5, ls='-.')
#       4 ax[0].set_title('x, y')
#       5 ax[0].set(xlabel='X axis', ylabel='Y axis')
#
# NameError: name 'ax' is not defined

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
df = pd.read_csv('vehicles.csv')
display(df.head(3))
# Out:
#          Make                Model  Year  Engine Displacement  Cylinders  \
# 0  AM General    DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General     FJ8c Post Office  1984                  4.2        6.0
# 2  AM General  Post Office DJ5 2WD  1985                  2.5        4.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
# 2          20.600625        16           17            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100

# %%
plt.scatter(x='Combined MPG', y='Highway MPG', color='tab:purple', data=df)

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
fig, ax1 = plt.subplots()
ax1.set_title('CO2 Emission Grams/Mile')
ax1.boxplot(df['CO2 Emission Grams/Mile'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x107d7aa20>,
#   <matplotlib.lines.Line2D at 0x107d7add8>],
#  'caps': [<matplotlib.lines.Line2D at 0x107d7aeb8>,
#   <matplotlib.lines.Line2D at 0x107d874a8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x107d7a630>],
#  'medians': [<matplotlib.lines.Line2D at 0x107d877f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x107d87b38>],
#  'means': []}

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
(df['Fuel Barrels/Year']).hist()

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
y_pos = np.arange(len(df['Fuel Type']))

plt.bar(y_pos, df['City MPG'], align='center')
plt.xticks(y_pos, df['City MPG'])

plt.show()
