# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data

# %%
import pymysql
import sqlalchemy

# %% [markdown]
# #### 3. Create a mysql engine to set the connection to the server. Check the connection details in [this link](https://relational.fit.cvut.cz/search?tableCount%5B%5D=0-10&tableCount%5B%5D=10-30&dataType%5B%5D=Numeric&databaseSize%5B%5D=KB&databaseSize%5B%5D=MB)

# %%
from sqlalchemy import create_engine

mysql_domain = "relational.fit.cvut.cz"
mysql_user = "guest"
mysql_password = 'relational'
mysql_db = "stats"

dbdata = [mysql_user, mysql_password, mysql_domain, mysql_db]
connection_url = 'mysql+pymysql://{}:{}@{}/{}'.format(*dbdata)
engine = create_engine(connection_url)
print("Connected to DB!")
# Out:
# Connected to DB!

# %% [markdown]
# #### 4. Import the users table

# %%
sqlquery = """
SELECT * FROM users
"""

users = pd.read_sql_query(sqlquery, engine)

users.head()
# Out:
#    Id  Reputation        CreationDate   DisplayName      LastAccessDate  \
# 0  -1           1 2010-07-19 06:55:26     Community 2010-07-19 06:55:26
# 1   2         101 2010-07-19 14:01:36  Geoff Dalgas 2013-11-12 22:07:23
# 2   3         101 2010-07-19 15:34:50  Jarrod Dixon 2014-08-08 06:42:58
# 3   4         101 2010-07-19 19:03:27        Emmett 2014-01-02 09:31:02
# 4   5        6792 2010-07-19 19:03:57         Shane 2014-08-13 00:23:47
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
# 1        http://stackoverflow.com       Corvallis, OR
# 2        http://stackoverflow.com        New York, NY
# 3    http://minesweeperonline.com   San Francisco, CA
# 4         http://www.statalgo.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...      0     5007
# ...

# %% [markdown]
# #### 5. Rename Id column to userId

# %%
users.rename(columns = {'Id':'UserId'}, inplace=True)
users.head()
# Out:
#    UserId  Reputation        CreationDate   DisplayName      LastAccessDate  \
# 0      -1           1 2010-07-19 06:55:26     Community 2010-07-19 06:55:26
# 1       2         101 2010-07-19 14:01:36  Geoff Dalgas 2013-11-12 22:07:23
# 2       3         101 2010-07-19 15:34:50  Jarrod Dixon 2014-08-08 06:42:58
# 3       4         101 2010-07-19 19:03:27        Emmett 2014-01-02 09:31:02
# 4       5        6792 2010-07-19 19:03:57         Shane 2014-08-13 00:23:47
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
# 1        http://stackoverflow.com       Corvallis, OR
# 2        http://stackoverflow.com        New York, NY
# 3    http://minesweeperonline.com   San Francisco, CA
# 4         http://www.statalgo.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...      0     5007
# ...

# %% [markdown]
# #### 6. Import the posts table.

# %%
sqlquery = """
SELECT * FROM posts
"""

posts = pd.read_sql_query(sqlquery, engine)

posts.head()
# Out:
#    Id  PostTypeId  AcceptedAnswerId         CreaionDate  Score  ViewCount  \
# 0   1           1              15.0 2010-07-19 19:12:12     23     1278.0
# 1   2           1              59.0 2010-07-19 19:12:57     22     8198.0
# 2   3           1               5.0 2010-07-19 19:13:28     54     3613.0
# 3   4           1             135.0 2010-07-19 19:13:31     13     5224.0
# 4   5           2               NaN 2010-07-19 19:14:43     81        NaN
#
#                                                 Body  OwnerUserId  \
# 0  <p>How should I elicit prior distributions fro...          8.0
# 1  <p>In many different statistical methods there...         24.0
# 2  <p>What are some valuable Statistical Analysis...         18.0
# 3  <p>I have two groups of data.  Each with a dif...         23.0
# 4  <p>The R-project</p>\n\n<p><a href="http://www...         23.0
#
#       LasActivityDate                                              Title  ...  \
# ...

# %% [markdown]
# #### 7. Rename Id column to postId and OwnerUserId to userId

# %%
posts.rename(columns = {'Id':'postId'}, inplace=True)
posts.head()

posts.rename(columns = {'OwnerUserId':'UserId'}, inplace=True)
posts.head()
# Out:
#    postId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  ViewCount  \
# 0       1           1              15.0 2010-07-19 19:12:12     23     1278.0
# 1       2           1              59.0 2010-07-19 19:12:57     22     8198.0
# 2       3           1               5.0 2010-07-19 19:13:28     54     3613.0
# 3       4           1             135.0 2010-07-19 19:13:31     13     5224.0
# 4       5           2               NaN 2010-07-19 19:14:43     81        NaN
#
#                                                 Body  UserId  \
# 0  <p>How should I elicit prior distributions fro...     8.0
# 1  <p>In many different statistical methods there...    24.0
# 2  <p>What are some valuable Statistical Analysis...    18.0
# 3  <p>I have two groups of data.  Each with a dif...    23.0
# 4  <p>The R-project</p>\n\n<p><a href="http://www...    23.0
#
#       LasActivityDate                                              Title  ...  \
# ...

# %% [markdown]
# #### 8. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userID,ViewCount,CommentCount

# %%
x = pd.DataFrame(users, columns = ['UserId', 'Reputation','Views','UpVotes','DownVotes'])
display(x.head())
# Out:
#    UserId  Reputation  Views  UpVotes  DownVotes
# 0      -1           1      0     5007       1920
# 1       2         101     25        3          0
# 2       3         101     22       19          0
# 3       4         101     11        0          0
# 4       5        6792   1145      662          5

# %%
b = pd.DataFrame(posts, columns = ['postId', 'Score','UserId','ViewCount','CommentCount'])
display(b.head(10))
# Out:
#    postId  Score  UserId  ViewCount  CommentCount
# 0       1     23     8.0     1278.0             1
# 1       2     22    24.0     8198.0             1
# 2       3     54    18.0     3613.0             4
# 3       4     13    23.0     5224.0             2
# 4       5     81    23.0        NaN             3
# 5       6    152     5.0    29229.0             5
# 6       7     76    38.0     5808.0             3
# 7       8      0    37.0      288.0             2
# 8       9     13    50.0        NaN             3
# 9      10     23    24.0    21925.0             4

# %% [markdown]
# #### 8. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
merge_df = pd.merge(x, b, 'inner')
merge_df.head()

#Tras comprobar los distintos merge he comprobado que haciendo un inner queda una muestra de 90584 entradas sin datos nulos, que representa el 82.1% de la muestra total que son 110318 y resulta suficiente para un anális estadístico.
# Out:
#    UserId  Reputation  Views  UpVotes  DownVotes  postId  Score  ViewCount  \
# 0      -1           1      0     5007       1920    2175      0        NaN
# 1      -1           1      0     5007       1920    8576      0        NaN
# 2      -1           1      0     5007       1920    8578      0        NaN
# 3      -1           1      0     5007       1920    8981      0        NaN
# 4      -1           1      0     5007       1920    8982      0        NaN
#
#    CommentCount
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %% [markdown]
# #### 9. How many missing values do you have in your merged dataframe? On which columns?

# %%
merge_df.isna().sum()
# Out:
# UserId              0
# Reputation          0
# Views               0
# UpVotes             0
# DownVotes           0
# postId              0
# Score               0
# ViewCount       48396
# CommentCount        0
# dtype: int64

# %% [markdown]
# #### 10. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %%
data_c = merge_df.drop('ViewCount', axis=1)
data_c.head()

#Se ha elminado la columna de conteo de visitas porque no aporta información relevante en una regresión lineal ya que es un campo calculado y además los nulos represntan un 43.9% sobre el total.
# Out:
#    UserId  Reputation  Views  UpVotes  DownVotes  postId  Score  CommentCount
# 0      -1           1      0     5007       1920    2175      0             0
# 1      -1           1      0     5007       1920    8576      0             0
# 2      -1           1      0     5007       1920    8578      0             0
# 3      -1           1      0     5007       1920    8981      0             0
# 4      -1           1      0     5007       1920    8982      0             0

# %%
data_c.isna().sum()
# Out:
# UserId          0
# Reputation      0
# Views           0
# UpVotes         0
# DownVotes       0
# postId          0
# Score           0
# CommentCount    0
# dtype: int64

# %% [markdown]
# #### 11. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
print(data_c.dtypes)

#Como se puede comprobar todas las variables contienen datos de la misma naturaleza por lo que no es necesario realziar modificaciones.
# Out:
# UserId          int64
# Reputation      int64
# Views           int64
# UpVotes         int64
# DownVotes       int64
# postId          int64
# Score           int64
# CommentCount    int64
# dtype: object

# %% [markdown]
# #### Bonus: Identify extreme values in your merged dataframe as you have learned in class, create a dataframe called outliers with the same columns as our data set and calculate the bounds. The values of the outliers dataframe will be the values of the merged_df that fall outside that bounds. You will need to save your outliers dataframe to a csv file on your-code folder.

# %%
data_c = data_clean.describe().transpose()
data_c['IQR'] = data_c['75%'] - data_c['25%']
data_c
# Out:
#                  count          mean           std   min       25%      50%  \
# UserId        108926.0  18827.148146  16308.484529  -1.0   4505.00  13413.0
# Reputation    108926.0   5231.223546  13968.878146   1.0     23.00    172.0
# Views         108926.0    860.178690   2654.748581   0.0      1.00     19.0
# UpVotes       108926.0    610.758221   1890.290982   0.0      0.00      7.0
# DownVotes     108926.0     27.670501    123.680361   0.0      0.00      0.0
# postId         91976.0  56147.699465  33975.569431   1.0  25489.75  56781.5
# Score          91976.0      2.791902      4.981867 -19.0      1.00      2.0
# CommentCount   91976.0      1.895114      2.639020   0.0      0.00      1.0
#
#                    75%       max      IQR
# UserId        30682.00   55747.0  26177.0
# Reputation     2294.00   87393.0   2271.0
# Views           293.00   20932.0    292.0
# UpVotes         167.00   11442.0    167.0
# DownVotes         5.00    1920.0      5.0
# ...

# %%
outliers = pd.DataFrame(columns=data_c.columns)

for col in data_c.index:
    iqr = data_c.at[col,'IQR']
    cutoff = iqr * 1.5
    lower = data_c.at[col,'25%'] - cutoff
    upper = data_c.at[col,'75%'] + cutoff
    results = data_clean[(data_clean[col] < lower) | 
                   (data_clean[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)

# %%
display(outliers.head())
# Out:
#      25%  50%  75%  CommentCount  DownVotes  IQR     Outlier  Reputation  \
# 214  NaN  NaN  NaN           5.0        5.0  NaN  Reputation      6792.0
# 215  NaN  NaN  NaN           1.0        5.0  NaN  Reputation      6792.0
# 216  NaN  NaN  NaN           0.0        5.0  NaN  Reputation      6792.0
# 217  NaN  NaN  NaN           0.0        5.0  NaN  Reputation      6792.0
# 218  NaN  NaN  NaN           0.0        5.0  NaN  Reputation      6792.0
#
#      Score  UpVotes  UserId   Views count  max mean  min  postId  std
# 214  152.0    662.0     5.0  1145.0   NaN  NaN  NaN  NaN     6.0  NaN
# 215   20.0    662.0     5.0  1145.0   NaN  NaN  NaN  NaN    12.0  NaN
# 216   12.0    662.0     5.0  1145.0   NaN  NaN  NaN  NaN    32.0  NaN
# 217    6.0    662.0     5.0  1145.0   NaN  NaN  NaN  NaN    49.0  NaN
# 218    6.0    662.0     5.0  1145.0   NaN  NaN  NaN  NaN    64.0  NaN
