# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data

# %%
import pymysql
import sqlalchemy
from sqlalchemy import create_engine
#import getpass

# %% [markdown]
# #### 3. Create a mysql engine to set the connection to the server. Check the connection details in [this link](https://relational.fit.cvut.cz/search?tableCount%5B%5D=0-10&tableCount%5B%5D=10-30&dataType%5B%5D=Numeric&databaseSize%5B%5D=KB&databaseSize%5B%5D=MB)

# %%
mysql_domain = "relational.fit.cvut.cz"
mysql_user = "guest"
#mysql_password = getpass.getpass()
mysql_password = "relational"
mysql_db = "stats"

dbdata = [mysql_user, mysql_password, mysql_domain, mysql_db]
connection_url = 'mysql+pymysql://{}:{}@{}/{}'.format(*dbdata)
engine = create_engine(connection_url)
print("Connected to DB!")
# Out:
# Connected to DB!

# %% [markdown]
# 4. Import the users table

# %%
sqlquery = """
SELECT * FROM users
"""
users = pd.read_sql_query(sqlquery, engine)
print(users.shape)
users.head()
# Out:
# (40325, 14)
#    Id  Reputation        CreationDate   DisplayName      LastAccessDate  \
# 0  -1           1 2010-07-19 06:55:26     Community 2010-07-19 06:55:26
# 1   2         101 2010-07-19 14:01:36  Geoff Dalgas 2013-11-12 22:07:23
# 2   3         101 2010-07-19 15:34:50  Jarrod Dixon 2014-08-08 06:42:58
# 3   4         101 2010-07-19 19:03:27        Emmett 2014-01-02 09:31:02
# 4   5        6792 2010-07-19 19:03:57         Shane 2014-08-13 00:23:47
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
# 1        http://stackoverflow.com       Corvallis, OR
# 2        http://stackoverflow.com        New York, NY
# 3    http://minesweeperonline.com   San Francisco, CA
# 4         http://www.statalgo.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...      0     5007
# 1  <p>Developer on the StackOverflow team.  Find ...     25        3
# 2  <p><a href="http://blog.stackoverflow.com/2009...     22       19
# 3  <p>currently at a startup in SF</p>\n\n<p>form...     11        0
# 4  <p>Quantitative researcher focusing on statist...   1145      662
#
#    DownVotes  AccountId   Age                     ProfileImageUrl
# 0       1920         -1   NaN                                None
# 1          0          2  37.0                                None
# 2          0          3  35.0                                None
# 3          0       1998  28.0  http://i.stack.imgur.com/d1oHX.jpg
# 4          5      54503  35.0                                None

# %%
users[(users['userId']== -1)]  #Solo hay un -1, queremos eliminarlo al final ! no es persona!!!!
# Out:
#    userId  Reputation        CreationDate DisplayName      LastAccessDate  \
# 0      -1           1 2010-07-19 06:55:26   Community 2010-07-19 06:55:26
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...      0     5007
#
#    DownVotes  AccountId  Age ProfileImageUrl
# 0       1920         -1  NaN            None

# %% [markdown]
# #### 5. Rename Id column to userId

# %%
users = users.rename(columns={"Id":"userId"})
#display (users)
users['userId'].head()
# Out:
# 0   -1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: userId, dtype: int64

# %% [markdown]
# #### 6. Import the posts table.

# %%
sqlquery_1 = """
SELECT * FROM posts
"""
posts = pd.read_sql_query(sqlquery_1, engine)
print(posts.shape)
posts.head()
# Out:
# (91976, 21)
#    Id  PostTypeId  AcceptedAnswerId         CreaionDate  Score  ViewCount  \
# 0   1           1              15.0 2010-07-19 19:12:12     23     1278.0
# 1   2           1              59.0 2010-07-19 19:12:57     22     8198.0
# 2   3           1               5.0 2010-07-19 19:13:28     54     3613.0
# 3   4           1             135.0 2010-07-19 19:13:31     13     5224.0
# 4   5           2               NaN 2010-07-19 19:14:43     81        NaN
#
#                                                 Body  OwnerUserId  \
# 0  <p>How should I elicit prior distributions fro...          8.0
# 1  <p>In many different statistical methods there...         24.0
# 2  <p>What are some valuable Statistical Analysis...         18.0
# 3  <p>I have two groups of data.  Each with a dif...         23.0
# 4  <p>The R-project</p>\n\n<p><a href="http://www...         23.0
#
#       LasActivityDate                                              Title  ...  \
# 0 2010-09-15 21:08:26                      Eliciting priors from experts  ...
# 1 2012-11-12 09:21:54                                 What is normality?  ...
# 2 2013-05-27 14:48:36  What are some valuable Statistical Analysis op...  ...
# 3 2010-09-08 03:00:19  Assessing the significance of differences in d...  ...
# 4 2010-07-19 19:21:15                                               None  ...
#
#   AnswerCount  CommentCount  FavoriteCount  LastEditorUserId  \
# 0         5.0             1           14.0               NaN
# 1         7.0             1            8.0              88.0
# 2        19.0             4           36.0             183.0
# 3         5.0             2            2.0               NaN
# 4         NaN             3            NaN              23.0
#
#          LastEditDate  CommunityOwnedDate ParentId  ClosedDate  \
# 0                 NaT                 NaT      NaN         NaT
# 1 2010-08-07 17:56:44                 NaT      NaN         NaT
# 2 2011-02-12 05:50:03 2010-07-19 19:13:28      NaN         NaT
# 3                 NaT                 NaT      NaN         NaT
# 4 2010-07-19 19:21:15 2010-07-19 19:14:43      3.0         NaT
#
#   OwnerDisplayName LastEditorDisplayName
# 0             None                  None
# 1             None                  None
# 2             None                  None
# 3             None                  None
# 4             None                  None
#
# [5 rows x 21 columns]

# %% [markdown]
# #### 7. Rename Id column to postId and OwnerUserId to userId

# %%
posts = posts.rename(columns={"Id":"postId", "OwnerUserId":"userId"})
posts.head()
# Out:
#    postId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  ViewCount  \
# 0       1           1              15.0 2010-07-19 19:12:12     23     1278.0
# 1       2           1              59.0 2010-07-19 19:12:57     22     8198.0
# 2       3           1               5.0 2010-07-19 19:13:28     54     3613.0
# 3       4           1             135.0 2010-07-19 19:13:31     13     5224.0
# 4       5           2               NaN 2010-07-19 19:14:43     81        NaN
#
#                                                 Body  userId  \
# 0  <p>How should I elicit prior distributions fro...     8.0
# 1  <p>In many different statistical methods there...    24.0
# 2  <p>What are some valuable Statistical Analysis...    18.0
# 3  <p>I have two groups of data.  Each with a dif...    23.0
# 4  <p>The R-project</p>\n\n<p><a href="http://www...    23.0
#
#       LasActivityDate                                              Title  ...  \
# 0 2010-09-15 21:08:26                      Eliciting priors from experts  ...
# 1 2012-11-12 09:21:54                                 What is normality?  ...
# 2 2013-05-27 14:48:36  What are some valuable Statistical Analysis op...  ...
# 3 2010-09-08 03:00:19  Assessing the significance of differences in d...  ...
# 4 2010-07-19 19:21:15                                               None  ...
#
#   AnswerCount  CommentCount  FavoriteCount  LastEditorUserId  \
# 0         5.0             1           14.0               NaN
# 1         7.0             1            8.0              88.0
# 2        19.0             4           36.0             183.0
# 3         5.0             2            2.0               NaN
# 4         NaN             3            NaN              23.0
#
#          LastEditDate  CommunityOwnedDate ParentId  ClosedDate  \
# 0                 NaT                 NaT      NaN         NaT
# 1 2010-08-07 17:56:44                 NaT      NaN         NaT
# 2 2011-02-12 05:50:03 2010-07-19 19:13:28      NaN         NaT
# 3                 NaT                 NaT      NaN         NaT
# 4 2010-07-19 19:21:15 2010-07-19 19:14:43      3.0         NaT
#
#   OwnerDisplayName LastEditorDisplayName
# 0             None                  None
# 1             None                  None
# 2             None                  None
# 3             None                  None
# 4             None                  None
#
# [5 rows x 21 columns]

# %% [markdown]
# #### 8. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userID,ViewCount,CommentCount

# %%
new_users = users[["userId","Reputation","Views","UpVotes","DownVotes"]] 
new_posts = posts[["postId","Score","userId","ViewCount","CommentCount"]]
new_users.head()
# Out:
#    userId  Reputation  Views  UpVotes  DownVotes
# 0      -1           1      0     5007       1920
# 1       2         101     25        3          0
# 2       3         101     22       19          0
# 3       4         101     11        0          0
# 4       5        6792   1145      662          5

# %%
new_posts.head()
# Out:
#    postId  Score  userId  ViewCount  CommentCount
# 0       1     23     8.0     1278.0             1
# 1       2     22    24.0     8198.0             1
# 2       3     54    18.0     3613.0             4
# 3       4     13    23.0     5224.0             2
# 4       5     81    23.0        NaN             3

# %% [markdown]
# #### 8. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
# mergeada = new_users.merge(new_posts, how='left', on='userId')
# mergeada.head()

print(new_users.dtypes)
print(new_posts.dtypes)
#A ver, al imprimir el tipo de cada serie de cada uno de los dataframes, userId
# en la primera (new_users), es int64
# en la segunda (new_posts), tipo float
# Out:
# userId        int64
# Reputation    int64
# Views         int64
# UpVotes       int64
# DownVotes     int64
# dtype: object
# postId            int64
# Score             int64
# userId          float64
# ViewCount       float64
# CommentCount      int64
# dtype: object

# %%
mergeada = new_users.merge(new_posts, how='outer', on='userId')
mergeada.head()
#display(mergeada)
display(mergeada[1000:3000])
# Out:
#       userId  Reputation  Views  UpVotes  DownVotes   postId  Score  \
# 1000    71.0      1936.0  328.0   2317.0        1.0   6173.0   10.0
# 1001    71.0      1936.0  328.0   2317.0        1.0   7855.0    5.0
# 1002    71.0      1936.0  328.0   2317.0        1.0   7885.0    3.0
# 1003    71.0      1936.0  328.0   2317.0        1.0   8050.0   14.0
# 1004    71.0      1936.0  328.0   2317.0        1.0   9596.0    2.0
# 1005    71.0      1936.0  328.0   2317.0        1.0  10050.0    1.0
# 1006    71.0      1936.0  328.0   2317.0        1.0  10582.0    2.0
# 1007    71.0      1936.0  328.0   2317.0        1.0  10721.0    6.0
# 1008    71.0      1936.0  328.0   2317.0        1.0  11240.0    2.0
# 1009    71.0      1936.0  328.0   2317.0        1.0  15547.0    1.0
# 2995   210.0       337.0   47.0     32.0        1.0  10232.0    3.0
# 2996   211.0       586.0   11.0      0.0        0.0    248.0    4.0
# 2997   211.0       586.0   11.0      0.0        0.0    286.0   12.0
# 2998   211.0       586.0   11.0      0.0        0.0    291.0    7.0
# 2999   211.0       586.0   11.0      0.0        0.0    293.0    4.0
#
#       ViewCount  CommentCount
# 1000        NaN           5.0
# 1001        NaN           0.0
# 1002        NaN           0.0
# 1003        NaN           7.0
# 1004      284.0           0.0
# 1005        NaN           3.0
# 1006        NaN           0.0
# 1007        NaN           9.0
# 1008        NaN           6.0
# 1009        NaN           2.0
# 1010        NaN           1.0
# 1011        NaN           0.0
# 1012        NaN           0.0
# 1013        NaN           5.0
# 1014        NaN           2.0
# 1015        NaN           1.0
# 1016        NaN           1.0
# 1017        NaN           2.0
# 1018        NaN           0.0
# 1019        NaN           8.0
# 1020        NaN           2.0
# 1021        NaN           4.0
# 1022      332.0           0.0
# 1023        NaN           2.0
# 1024      200.0           5.0
# 1025        NaN           0.0
# 1026      407.0           4.0
# 1027        NaN           6.0
# 1028        NaN           0.0
# 1029        NaN           9.0
# ...         ...           ...
# 2970     2519.0          11.0
# 2971        NaN           4.0
# 2972        NaN           0.0
# 2973        NaN           3.0
# 2974      219.0           5.0
# 2975        NaN           0.0
# 2976      197.0           3.0
# 2977       52.0           3.0
# 2978        NaN           0.0
# 2979       61.0           0.0
# 2980        NaN           NaN
# 2981        NaN           NaN
# 2982        NaN           NaN
# 2983        NaN           NaN
# 2984        NaN           NaN
# 2985        NaN           0.0
# 2986      174.0           1.0
# 2987        NaN           3.0
# 2988        NaN           2.0
# 2989      534.0           3.0
# 2990      441.0           0.0
# 2991        NaN           2.0
# 2992      373.0           0.0
# 2993        NaN           0.0
# 2994        NaN           0.0
# 2995        NaN           6.0
# 2996        NaN           0.0
# 2997        NaN           0.0
# 2998        NaN           0.0
# 2999        NaN           1.0
#
# [2000 rows x 9 columns]

# %% [markdown]
# #### 9. How many missing values do you have in your merged dataframe? On which columns?

# %%
posts.columns
#posts['userId'].isnull()
#posts[(posts['userId'].isnull())]
posts[(posts['userId'] == -1)]
# Out:
#        postId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 2040     2175           7               NaN 2010-08-28 01:20:33      0
# 7898     8576           5               NaN 2011-03-21 17:40:28      0
# 7900     8578           5               NaN 2011-03-21 17:46:43      0
# 8259     8981           3               NaN 2011-03-30 19:23:14      0
# 8260     8982           3               NaN 2011-03-30 19:23:14      0
# 9050     9857           3               NaN 2011-04-22 06:59:10      0
# 9051     9858           3               NaN 2011-04-22 06:59:10      0
# 9053     9860           5               NaN 2011-04-22 07:09:42      0
# 9302    10130           3               NaN 2011-04-29 00:18:02      0
# 9303    10131           3               NaN 2011-04-29 00:18:02      0
# 14025   15331           5               NaN 2011-09-08 14:55:01      0
# 14026   15332           4               NaN 2011-09-08 14:55:01      0
# 14903   16296           5               NaN 2011-09-30 18:31:08      0
# 14968   16366           5               NaN 2011-10-02 18:27:56      0
# 17686   19423           5               NaN 2011-12-06 09:43:26      0
# 9303         NaN                                               None    -1.0
# 14025        NaN  <p>The term propensity-score comes from the li...    -1.0
# 14026        NaN  The probability of receiving a treatment given...    -1.0
# 14903        NaN  <p><a href="http://en.wikipedia.org/wiki/Struc...    -1.0
# 14968        NaN                                               None    -1.0
# 17686        NaN                                               None    -1.0
# 18066        NaN                                               None    -1.0
# 18432        NaN  <p>In statistics, a number that expresses the ...    -1.0
# 18434        NaN  <p>Statistical classification is the problem o...    -1.0
# 18435        NaN  Statistical classification is the problem of i...    -1.0
# 18436        NaN  <p>A statistical model is a formalization of r...    -1.0
# 18437        NaN  A statistical model is a formalization of rela...    -1.0
# 18639        NaN                                               None    -1.0
# 18641        NaN                                               None    -1.0
# 18643        NaN  <p>Structured data files in any format, collec...    -1.0
# 18644        NaN  Structured data files in any format, collected...    -1.0
# 19514        NaN                                               None    -1.0
# 19774        NaN                                               None    -1.0
# 19823        NaN                                               None    -1.0
# 19827        NaN                                               None    -1.0
# 19828        NaN                                               None    -1.0
# ...          ...                                                ...     ...
# 56665        NaN  <p>Combinatorics is "parent" of probability in...    -1.0
# 57150        NaN  <p>\n    On Stack Exchange, we believe the cor...    -1.0
# 57704        NaN                                               None    -1.0
# 59108        NaN                                               None    -1.0
# 59930        NaN                                               None    -1.0
# 60222        NaN                                               None    -1.0
# 60391        NaN                                               None    -1.0
# 64459        NaN                                               None    -1.0
# 65245        NaN                                               None    -1.0
# 65253        NaN                                               None    -1.0
# 65255        NaN                                               None    -1.0
# 65339        NaN                                               None    -1.0
# 65713        NaN                                               None    -1.0
# 67581        NaN                                               None    -1.0
# 70070        NaN                                               None    -1.0
# 73050        NaN                                               None    -1.0
# 73051        NaN                                               None    -1.0
# 76109        NaN                                               None    -1.0
# 79235        NaN                                               None    -1.0
# 79394        NaN                                               None    -1.0
# 79627        NaN                                               None    -1.0
# 80447        NaN                                               None    -1.0
# 81927        NaN                                               None    -1.0
# 82029        NaN        A "memoryless" discrete stochastic process.    -1.0
# 83563        NaN                                               None    -1.0
# 85129        NaN                                               None    -1.0
# 86681        NaN                                               None    -1.0
# 88996        NaN                                               None    -1.0
# 88998        NaN                                               None    -1.0
# 89398        NaN                                               None    -1.0
#
#           LasActivityDate Title  ... AnswerCount  CommentCount  FavoriteCount  \
# 2040  2013-01-10 19:43:24  None  ...         NaN             0            NaN
# 7898  2011-03-21 17:40:28  None  ...         NaN             0            NaN
# 7900  2011-03-21 17:46:43  None  ...         NaN             0            NaN
# 8259  2011-03-30 19:23:14  None  ...         NaN             0            NaN
# 8260  2011-03-30 19:23:14  None  ...         NaN             0            NaN
# 9050  2011-04-22 06:59:10  None  ...         NaN             0            NaN
# 9051  2011-04-22 09:24:38  None  ...         NaN             0            NaN
# 9053  2011-04-22 07:09:42  None  ...         NaN             0            NaN
# 9302  2011-04-29 00:18:02  None  ...         NaN             0            NaN
# 9303  2011-04-29 00:18:02  None  ...         NaN             0            NaN
# 14025 2011-09-08 15:01:38  None  ...         NaN             0            NaN
# 14026 2011-09-08 15:01:36  None  ...         NaN             0            NaN
# 14903 2014-04-09 14:52:13  None  ...         NaN             0            NaN
#
#        LastEditorUserId        LastEditDate CommunityOwnedDate ParentId  \
# 2040               -1.0 2014-04-23 13:43:43                NaT      NaN
# 7898               -1.0 2011-03-21 17:40:28                NaT      NaN
# 7900               -1.0 2011-03-21 17:46:43                NaT      NaN
# 8259              919.0 2011-03-30 19:23:14                NaT      NaN
# 8260              919.0 2011-03-30 19:23:14                NaT      NaN
# 9050               -1.0 2011-04-22 06:59:10                NaT      NaN
# 9051             2116.0 2011-04-22 09:24:38                NaT      NaN
# 9053               -1.0 2011-04-22 07:09:42                NaT      NaN
# 9302               -1.0 2011-04-29 00:18:02                NaT      NaN
# 9303               -1.0 2011-04-29 00:18:02                NaT      NaN
# 14025               NaN 2011-09-08 15:01:38                NaT      NaN
# 14026               NaN 2011-09-08 15:01:36                NaT      NaN
# 14903            7290.0 2014-04-09 14:52:13                NaT      NaN
# 14968              -1.0 2011-10-02 18:27:56                NaT      NaN
# 17686              -1.0 2011-12-06 09:43:26                NaT      NaN
# 18066              -1.0 2011-12-15 02:38:20                NaT      NaN
# 18432               NaN 2011-12-27 08:23:52                NaT      NaN
# 18434               NaN 2011-12-27 08:23:34                NaT      NaN
# 18435               NaN 2011-12-27 08:23:37                NaT      NaN
# 18436               NaN 2011-12-27 08:23:40                NaT      NaN
# 18437               NaN 2011-12-27 08:23:43                NaT      NaN
# 18639              -1.0 2012-01-02 18:07:38                NaT      NaN
# 18641              -1.0 2012-01-02 18:08:36                NaT      NaN
# 18643               NaN 2012-01-02 18:17:13                NaT      NaN
# 18644               NaN 2012-01-02 18:17:10                NaT      NaN
# 19514              -1.0 2012-01-22 15:04:34                NaT      NaN
# 19774              -1.0 2012-01-27 01:25:07                NaT      NaN
# 19823              -1.0 2012-01-28 09:37:15                NaT      NaN
# 19827              -1.0 2012-01-28 09:46:15                NaT      NaN
# 19828              -1.0 2012-01-28 09:46:15                NaT      NaN
# ...                 ...                 ...                ...      ...
# 56665             919.0 2013-09-10 15:59:55                NaT      NaN
# 57150            8588.0 2013-09-17 15:16:34                NaT      NaN
# 57704              -1.0 2013-09-24 13:04:42                NaT      NaN
# 59108              -1.0 2013-10-11 11:26:16                NaT      NaN
# 59930              -1.0 2013-10-22 15:20:37                NaT      NaN
# 60222              -1.0 2013-10-26 19:31:28                NaT      NaN
# 60391              -1.0 2013-10-29 13:11:25                NaT      NaN
# 64459              -1.0 2013-12-15 17:41:42                NaT      NaN
# 65245              -1.0 2013-12-27 20:40:52                NaT      NaN
# 65253              -1.0 2013-12-27 21:31:41                NaT      NaN
# 65255              -1.0 2013-12-27 21:38:10                NaT      NaN
# 65339              -1.0 2013-12-29 01:56:12                NaT      NaN
# 65713              -1.0 2014-01-04 11:54:14                NaT      NaN
# 67581              -1.0 2014-01-25 13:12:36                NaT      NaN
# 70070              -1.0 2014-02-19 14:52:31                NaT      NaN
# 73050              -1.0 2014-03-20 07:01:12                NaT      NaN
# 73051              -1.0 2014-03-20 07:01:12                NaT      NaN
# 76109              -1.0 2014-04-18 18:44:43                NaT      NaN
# 79235              -1.0 2014-05-15 15:51:46                NaT      NaN
# 79394              -1.0 2014-05-17 07:42:10                NaT      NaN
# 79627              -1.0 2014-05-19 16:50:22                NaT      NaN
# 80447              -1.0 2014-05-27 16:32:27                NaT      NaN
# 81927              -1.0 2014-06-11 03:32:12                NaT      NaN
# 82029             919.0 2014-06-11 22:19:45                NaT      NaN
# 83563              -1.0 2014-06-26 07:05:25                NaT      NaN
# 85129              -1.0 2014-07-11 20:28:02                NaT      NaN
# 86681              -1.0 2014-07-26 11:24:59                NaT      NaN
# 88996              -1.0 2014-08-15 19:33:34                NaT      NaN
# 88998              -1.0 2014-08-15 19:34:31                NaT      NaN
# 89398              -1.0 2014-08-19 20:16:36                NaT      NaN
#
#        ClosedDate OwnerDisplayName LastEditorDisplayName
# 2040          NaT             None                  None
# 7898          NaT             None                  None
# 7900          NaT             None                  None
# 8259          NaT             None                  None
# 8260          NaT             None                  None
# 9050          NaT             None                  None
# 9051          NaT             None                  None
# 9053          NaT             None                  None
# 9302          NaT             None                  None
# 9303          NaT             None                  None
# 14025         NaT             None              user5644
# 14026         NaT             None              user5644
# 14903         NaT             None                  None
# 14968         NaT             None                  None
# 17686         NaT             None                  None
# 18066         NaT             None                  None
# 18432         NaT             None              user7997
# 18434         NaT             None              user7997
# 18435         NaT             None              user7997
# 18436         NaT             None              user7997
# 18437         NaT             None              user7997
# 18639         NaT             None                  None
# 18641         NaT             None                  None
# 18643         NaT             None              user7997
# 18644         NaT             None              user7997
# 19514         NaT             None                  None
# 19774         NaT             None                  None
# 19823         NaT             None                  None
# 19827         NaT             None                  None
# 19828         NaT             None                  None
# ...           ...              ...                   ...
# 56665         NaT             None                  None
# 57150         NaT             None                  None
# 57704         NaT             None                  None
# 59108         NaT             None                  None
# 59930         NaT             None                  None
# 60222         NaT             None                  None
# 60391         NaT             None                  None
# 64459         NaT             None                  None
# 65245         NaT             None                  None
# 65253         NaT             None                  None
# 65255         NaT             None                  None
# 65339         NaT             None                  None
# 65713         NaT             None                  None
# 67581         NaT             None                  None
# 70070         NaT             None                  None
# 73050         NaT             None                  None
# 73051         NaT             None                  None
# 76109         NaT             None                  None
# 79235         NaT             None                  None
# 79394         NaT             None                  None
# 79627         NaT             None                  None
# 80447         NaT             None                  None
# 81927         NaT             None                  None
# 82029         NaT             None                  None
# 83563         NaT             None                  None
# 85129         NaT             None                  None
# 86681         NaT             None                  None
# 88996         NaT             None                  None
# 88998         NaT             None                  None
# 89398         NaT             None                  None
#
# [211 rows x 21 columns]

# %%
#NaN 
#print(mergeada["ViewCount"].value_counts())
print((set(mergeada["ViewCount"]))
mergeada.shape
# Out:
#   File "<ipython-input-66-8a11fc083aaf>", line 4
#     mergeada.shape
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 10. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %% [markdown]
# #### 11. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %% [markdown]
# #### Bonus: Identify extreme values in your merged dataframe as you have learned in class, create a dataframe called outliers with the same columns as our data set and calculate the bounds. The values of the outliers dataframe will be the values of the merged_df that fall outside that bounds. You will need to save your outliers dataframe to a csv file on your-code folder.
