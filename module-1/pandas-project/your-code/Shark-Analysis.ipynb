# %%
import pandas as pd
shark_attack = pd.read_csv("clean_sharks_attack.csv")
display(shark_attack)
# Out:
#       Unnamed: 0   Case Number                      Date  Year          Type  \
# 0              4    2016.09.15                 16-Sep-16  2016    Unprovoked
# 1              6    2016.09.11                 11-Sep-16  2016    Unprovoked
# 2              7    2016.09.07                 07-Sep-16  2016    Unprovoked
# 3             12    2016.09.01                 01-Sep-16  2016    Unprovoked
# 4             13  2016.08.29.b                 29-Aug-16  2016    Unprovoked
# 5             15    2016.08.27                 27-Aug-16  2016    Unprovoked
# 6             18    2016.08.06                 06-Aug-16  2016    Unprovoked
# 7             19    2016.08.04                 04-Aug-16  2016    Unprovoked
# 8             20    2016.07.29                 29-Jul-16  2016    Unprovoked
# 9             22    2016.07.28                 28-Jul-16  2016          Boat
# 10            23    2016.07.27                 27-Jul-16  2016      Provoked
# ...

# %% [markdown]
# Primero relaciono

# %%
sharks_columns_1= shark_attack[['Species','Fatal (Y/N)','Activity']]

# %%
display(sharks_columns_1)
# Out:
#                      Species Fatal (Y/N)          Activity
# 0               MEDIUM SHARK          NO        Surf_sport
# 1                SMALL SHARK          NO     Leisure_beach
# 2                TIGER SHARK          NO     Leisure_beach
# 3                WHITE SHARK          NO  Fishing_activity
# 4                 BULL SHARK          NO        Surf_sport
# 5                 BULL SHARK          NO        Surf_sport
# 6                TIGER SHARK          NO        Surf_sport
# 7             BLACKTIP SHARK          NO        Surf_sport
# 8                 BLUE SHARK          NO     Leisure_beach
# 9                WHITE SHARK          NO     Rowing_sports
# 10               NURSE SHARK          NO  Fishing_activity
# 11                BULL SHARK          NO  Fishing_activity
# 12                    OTHERS          NO  Fishing_activity
# 13               TIGER SHARK          NO  Fishing_activity
# 14               LEMON SHARK          NO        Dive_sport
# ...

# %%
#sharks_columns_1 = sharks_columns_1.drop(sharks_columns_1[sharks_columns_1['Species']=='OTHERS'].index)

# %%
#display(sharks_columns_1)

# %%
sharks_columns_1= sharks_columns_1.drop(sharks_columns_1[sharks_columns_1['Fatal (Y/N)']=='NO'].index)
display(sharks_columns_1)
# Out:
#                      Species Fatal (Y/N)          Activity
# 29                    OTHERS         YES        Dive_sport
# 31       BRONZE WHALER SHARK     Unknown  Fishing_activity
# 33               WHITE SHARK         YES        Surf_sport
# 44               TIGER SHARK         YES     Leisure_beach
# 104              WHITE SHARK         YES        Dive_sport
# 136               BULL SHARK         YES        Dive_sport
# 143               BULL SHARK         YES        Surf_sport
# 146                   OTHERS         YES        Dive_sport
# 148      SHORTFIN MAKO SHARK         YES     Leisure_beach
# 153              TIGER SHARK         YES     Leisure_beach
# 154             MEDIUM SHARK         YES        Surf_sport
# 168              WHITE SHARK         YES  Fishing_activity
# 191             MEDIUM SHARK         YES     Leisure_beach
# 208                   OTHERS         YES      Sea_accident
# 214                   OTHERS         YES        Dive_sport
# ...

# %%
sharks_columns_DEAD= sharks_columns_1.drop(sharks_columns_1[sharks_columns_1['Fatal (Y/N)']=='Unknown'].index)
display(sharks_columns_DEAD)
# Out:
#                      Species Fatal (Y/N)          Activity
# 29                    OTHERS         YES        Dive_sport
# 33               WHITE SHARK         YES        Surf_sport
# 44               TIGER SHARK         YES     Leisure_beach
# 104              WHITE SHARK         YES        Dive_sport
# 136               BULL SHARK         YES        Dive_sport
# 143               BULL SHARK         YES        Surf_sport
# 146                   OTHERS         YES        Dive_sport
# 148      SHORTFIN MAKO SHARK         YES     Leisure_beach
# 153              TIGER SHARK         YES     Leisure_beach
# 154             MEDIUM SHARK         YES        Surf_sport
# 168              WHITE SHARK         YES  Fishing_activity
# 191             MEDIUM SHARK         YES     Leisure_beach
# 208                   OTHERS         YES      Sea_accident
# 214                   OTHERS         YES        Dive_sport
# 236              WHITE SHARK         YES     Leisure_beach
# ...

# %%
Species_Activity= sharks_columns_DEAD[['Species','Activity']]
display(Species_Activity)
# Out:
#                      Species          Activity
# 29                    OTHERS        Dive_sport
# 33               WHITE SHARK        Surf_sport
# 44               TIGER SHARK     Leisure_beach
# 104              WHITE SHARK        Dive_sport
# 136               BULL SHARK        Dive_sport
# 143               BULL SHARK        Surf_sport
# 146                   OTHERS        Dive_sport
# 148      SHORTFIN MAKO SHARK     Leisure_beach
# 153              TIGER SHARK     Leisure_beach
# 154             MEDIUM SHARK        Surf_sport
# 168              WHITE SHARK  Fishing_activity
# 191             MEDIUM SHARK     Leisure_beach
# 208                   OTHERS      Sea_accident
# 214                   OTHERS        Dive_sport
# 236              WHITE SHARK     Leisure_beach
# 237             MEDIUM SHARK     Leisure_beach
# 252              TIGER SHARK        Surf_sport
# 253              WHITE SHARK        Surf_sport
# 264              WHITE SHARK        Dive_sport
# ...

# %%
Species_Activity=pd.crosstab(Species_Activity.Species, Species_Activity.Activity)

# %%
display(Species_Activity)
# Out:
# Activity                 Browsing  Dive_sport  Fishing_activity  \
# Species
# BASKING SHARK                   0           0                 2
# BIG SHARK                       8           5                 5
# BLACKTIP SHARK                  0           1                 0
# BLUE SHARK                      2           0                 3
# BRONZE WHALER SHARK             0           0                 2
# BULL SHARK                      0           6                 5
# DUSKY SHARK                     0           0                 0
# GALAPAGOS SHARK                 0           0                 0
# GREAT HAMMERHEAD SHARK          0           0                 1
# MEDIUM SHARK                    0           5                 5
# NURSE SHARK                     0           0                 0
# OCEANIC WHITETIP SHARK          2           3                 1
# OTHERS                          8          11                16
# ...

# %%
import matplotlib.pyplot
# %matplotlib inline

# %%
Species_Activity.plot.bar(figsize=(20,10), stacked=True)

# %%
Species_Activity.append(Species_Activity.sum().rename('TOTAL')).assign(TOTAL=lambda d: d.sum(1))
# Out:
# Activity                 Browsing  Dive_sport  Fishing_activity  \
# Species
# BASKING SHARK                   0           0                 2
# BIG SHARK                       8           5                 5
# BLACKTIP SHARK                  0           1                 0
# BLUE SHARK                      2           0                 3
# BRONZE WHALER SHARK             0           0                 2
# BULL SHARK                      0           6                 5
# DUSKY SHARK                     0           0                 0
# GALAPAGOS SHARK                 0           0                 0
# GREAT HAMMERHEAD SHARK          0           0                 1
# MEDIUM SHARK                    0           5                 5
# NURSE SHARK                     0           0                 0
# OCEANIC WHITETIP SHARK          2           3                 1
# OTHERS                          8          11                16
# ...

# %%
Species_killer_sharks=sharks_columns_DEAD.groupby('Species').count()
display(Species_killer_sharks)

# %%
sharks_columns_2= shark_attack[['Activity','Fatal (Y/N)']]
display(sharks_columns_2)

# %%
Activitys_columns_DEAD= sharks_columns_2.drop(sharks_columns_2[sharks_columns_2['Fatal (Y/N)']=='Unknown'].index)
display(Activitys_columns_DEAD)

# %%
Activitys_columns_DEAD.drop(Activitys_columns_DEAD[Activitys_columns_DEAD['Fatal (Y/N)']=='NO'].index)

# %%
Activity_dangerous_sharks=Activitys_columns_DEAD.groupby('Activity').count()
display(Activity_dangerous_sharks)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Species_killer_sharks.plot(figsize=(20,10))

# %%
Activity_dangerous_sharks.plot(figsize=(20,10))

# %%
table = df.pivot(index='Country',columns='Year',values='Value')  
print (table)
