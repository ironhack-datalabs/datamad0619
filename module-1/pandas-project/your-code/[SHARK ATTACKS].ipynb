# %%
import pandas as pd
df_ataques = pd.read_csv('../attacks.csv', encoding = "ISO-8859-1")
#display(df_ataques)
df_ataques.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
df_ataques.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#A
#Valores nulos:
print("TOTAL FILAS:", len(df_ataques))
df_ataques.isnull().sum()
# Out:
# TOTAL FILAS: 25723
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
    #print(list(df_ataques["Case Number"].unique()))
#WHEN NO DATE GIVEN
    #a = df_ataques["Case Number"].str.startswith("ND")
df_ataques['Case Number'].value_counts()
#OK, len = 6287 de estos, 2400 son 0


#Voy a ver a qué corresponden estos ceros en el resto de columnas:
# Out:
# 0                 2400
# 2014.08.02           2
# 1966.12.26           2
# 2012.09.02.b         2
# 1915.07.06.a.R       2
# 1907.10.16.R         2
# 1913.08.27.R         2
# 1920.00.00.b         2
# 1983.06.15           2
# 1923.00.00.a         2
# 2009.12.18           2
# 1990.05.10           2
# 1980.07.00           2
# 1962.06.11.b         2
# 2006.09.02           2
# 2005.04.06           2
# 2013.10.05           2
# 2007.07.18.b         1
# 1978.04.02.b         1
# 2016.06.05.a         1
# 1916.12.08.b         1
# 1981.09.03.a         1
# 2016.12.19           1
# 2015.06.24.b         1
# 1976.07.21           1
# 1942.12.26           1
# 1987.08.20           1
# 2017.01.09           1
# 1952.12.14           1
# 1935.05.12           1
#                   ...
# 2007.12.18           1
# 2014.10.05.b         1
# 2016.03.31           1
# 1855.00.00           1
# 1929.02.08           1
# 1882.11.12.b         1
# 2000.07.16.a         1
# 1994.03.23.a         1
# 1948.12.27           1
# ...

# %%
#CORRESPONDENCIA DE LOS 0 
nulos = df_ataques[df_ataques['Case Number'] == '0']
df_ataques[df_ataques['Case Number'] == '0'].index
print(nulos)
    #desde la fila 6302 hasta la 8701 
nulos.isnull().sum()
    #Prácticamente todos son nulos, y en la columna " Case Number" son 0. Voy a deshacerme de estas filas.
# Out:
#      Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 6302           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6303           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6304           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6305           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6306           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6307           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6308           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6309           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6310           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6311           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6312           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 6313           0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...

# %%
#Remove filas 0-nulo
#df_ataques.drop(range(),axis=0)
df_ataques_l = df_ataques.drop(df_ataques[df_ataques['Case Number'] == '0'].index)
display(df_ataques_l)
df_ataques_l.isnull().sum()
    #VEO LAS COLUMNAS CON MÁS DE x nulos
    #remove unnamed 22 y 23
# Out:
#         Case Number                  Date    Year          Type       Country  \
# 0        2018.06.25           25-Jun-2018  2018.0       Boating           USA
# 1        2018.06.18           18-Jun-2018  2018.0    Unprovoked           USA
# 2        2018.06.09           09-Jun-2018  2018.0       Invalid           USA
# 3        2018.06.08           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4        2018.06.04           04-Jun-2018  2018.0      Provoked        MEXICO
# 5      2018.06.03.b           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6      2018.06.03.a           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7        2018.05.27           27-May-2018  2018.0    Unprovoked           USA
# 8      2018.05.26.b           26-May-2018  2018.0    Unprovoked           USA
# 9      2018.05.26.a           26-May-2018  2018.0    Unprovoked           USA
# 10       2018.05.24           24-May-2018  2018.0      Provoked     AUSTRALIA
# ...

# %%
ataques = df_ataques_l[pd.notnull(df_ataques_l['Case Number'])]
ataques = ataques.drop(ataques.index[-1])

display(ataques)
# Out:
#        Case Number                                               Date    Year  \
# 0       2018.06.25                                        25-Jun-2018  2018.0
# 1       2018.06.18                                        18-Jun-2018  2018.0
# 2       2018.06.09                                        09-Jun-2018  2018.0
# 3       2018.06.08                                        08-Jun-2018  2018.0
# 4       2018.06.04                                        04-Jun-2018  2018.0
# 5     2018.06.03.b                                        03-Jun-2018  2018.0
# 6     2018.06.03.a                                        03-Jun-2018  2018.0
# 7       2018.05.27                                        27-May-2018  2018.0
# 8     2018.05.26.b                                        26-May-2018  2018.0
# 9     2018.05.26.a                                        26-May-2018  2018.0
# 10      2018.05.24                                        24-May-2018  2018.0
# ...
