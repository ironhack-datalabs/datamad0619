# %% [markdown]
# # LIMPIEZA DE LA BASE DE DATOS

# %% [markdown]
# INTRODUCCIÓN:
#
# PARA EL PRESENTE ANÁLISIS SE HA USADO ESTA BASE DE DATOS PARA SEGMENTAR EL PÚBLICO OBJETIVO ANTE EL LANZAMIENTO DE UN PRODUCTO QUE HA SIDO DISEÑADO PARA PREVENIR SITIUACIONES DE RIESGO ANTE EL ATAQUE DE TIBURONES ASÍ COMO LA ÉPOCA DEL AÑO EN LA QUE SERÍA MÁS FACIL PENETRAR EN EL MERCADO

# %% [markdown]
# IMPORTACIÓN DE LA BASE DE DATOS Y LIBRERÍAS

# %%
import pandas as pd
import re
import matplotlib

# %%
SharksBBDD = pd.read_csv('./GSAF5.csv', engine= "python")

# %% [markdown]
# RECUENTO DE VALORES NULOS:

# %%
SharksBBDD.isna().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         3
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %% [markdown]
# BORRADO DE COLUMNAS PRESCINDIBLES PARA EL ESTUDIO

# %%
SharksBBDD.drop(['Unnamed: 22', 'Unnamed: 23', 'Time', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order', 'Injury', 'Name', 'Species ', 'Investigator or Source'] , axis=1, inplace=True)

# %%
SharksBBDD.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Sex ', 'Age', 'Fatal (Y/N)'],
#       dtype='object')

# %% [markdown]
# SUSTITUIR VALORES NULOS POR "Unknown"

# %%
SharknoNa = SharksBBDD[['Case Number', 'Date', 'Year', 'Type','Country', 'Area', 'Location', 'Activity', 'Sex ', 'Age', 'Fatal (Y/N)']].fillna('Unknown')
SharknoNa.head(20)
# Out:
#      Case Number       Date  Year        Type        Country  \
# 0   2016.09.18.c  18-Sep-16  2016  Unprovoked            USA
# 1   2016.09.18.b  18-Sep-16  2016  Unprovoked            USA
# 2   2016.09.18.a  18-Sep-16  2016  Unprovoked            USA
# 3     2016.09.17  17-Sep-16  2016  Unprovoked      AUSTRALIA
# 4     2016.09.15  16-Sep-16  2016  Unprovoked      AUSTRALIA
# 5   2016.09.15.R  15-Sep-16  2016        Boat      AUSTRALIA
# 6     2016.09.11  11-Sep-16  2016  Unprovoked            USA
# 7     2016.09.07  07-Sep-16  2016  Unprovoked            USA
# 8     2016.09.06  06-Sep-16  2016  Unprovoked  NEW CALEDONIA
# 9   2016.09.05.b  05-Sep-16  2016  Unprovoked            USA
# 10  2016.09.05.a  05-Sep-16  2016  Unprovoked      AUSTRALIA
# 11    2016.09.04  04-Sep-16  2016  Unprovoked            USA
# 12    2016.09.01  01-Sep-16  2016  Unprovoked            USA
# 13  2016.08.29.b  29-Aug-16  2016  Unprovoked            USA
# ...

# %% [markdown]
# RECUENTO Y  LIMPIEZA DE LA VARIABLE DATE

# %%
SharknoNa['Date'].value_counts()
# Out:
# 1957                    11
# 1942                     9
# 1956                     8
# 1958                     7
# 1950                     7
# 1941                     7
# 1949                     6
# No date                  6
# 1940                     5
# 1970s                    5
# Oct-60                   5
# 1955                     5
# No date, Before 1963     5
# 12-Apr-01                5
# 28-Jul-95                5
# 1959                     5
# Aug-56                   5
# 05-Oct-03                5
# 1954                     5
# 28-Dec-14                4
# 14-Jun-12                4
# 09-Jan-10                4
# Before 1906              4
# 1890                     4
# 1960                     4
# Before 1958              4
# 1960s                    4
# 1952                     4
# 09-Jul-94                4
# 27-Jul-52                4
#                         ..
# 28-Jul-59                1
# Ca. 1911                 1
# 17-Sep-76                1
# ...

# %%
def findmes (m):
    m = str(m)
    if len(re.findall('\-\w+\-',m))==0:
        return '-'
    else:
        t= re.findall('\-\w+\-',m)
        return t[0][1:4]

# %%
SharknoNa['Date']= SharknoNa['Date'].apply(findmes)

# %% [markdown]
# A continuación se eliminarán los elementos Ap-, 26-, 30- y Jut, ya que no queda claro su valor y no suponen un valor representativo

# %%
SharknoNa1=SharknoNa1[SharknoNa['Date']!='Ap-']
# Out:
# /home/javier/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
SharknoNa1=SharknoNa1[SharknoNa['Date']!='30-']
# Out:
# /home/javier/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
SharknoNa1=SharknoNa1[SharknoNa['Date']!='Jut']
# Out:
# /home/javier/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
SharknoNa1=SharknoNa1[SharknoNa['Date']!='26-']
# Out:
# /home/javier/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
SharknoNa1['Date'].value_counts()
# Out:
# Jul    72
# Jun    60
# Aug    49
# Sep    48
# May    45
# Oct    41
# -      35
# Mar    32
# Jan    31
# Nov    27
# Dec    27
# Apr    25
# Feb    20
# Name: Date, dtype: int64

# %% [markdown]
# DADO QUE LA NATURALEZA DE LA INVESTIGACIÓN ES PARA EL LANZAMIENTO DE UN PRODUCTO ES CONVENIENTE ACOTAR LA POBLACIÓN A LAS TRES ÚLTIMAS DÉCADAS DONDE SE ENCUENTRA LA POBLACIÓN ACTUAL

# %%
SharknoNa1=SharknoNa1[SharknoNa1['Year']>=1990]
display(SharknoNa1)
# Out:
#        Case Number Date  Year        Type             Country  \
# 5     2016.09.15.R  Sep  2016        Boat           AUSTRALIA
# 7       2016.09.07  Sep  2016  Unprovoked                 USA
# 9     2016.09.05.b  Sep  2016  Unprovoked                 USA
# 29      2016.07.17  Jul  2016        Boat                 USA
# 30    2016.07.16.b  Jul  2016  Unprovoked                 USA
# 31    2016.07.16.a  Jul  2016  Unprovoked                 USA
# 34    2016.07.08.R  Jul  2016  Unprovoked               SPAIN
# 38      2016.07.06  Jul  2016  Unprovoked                 USA
# 48      2016.06.14  Jun  2016  Unprovoked                 USA
# 52    2016.06.05.a  Jun  2016  Unprovoked           AUSTRALIA
# 57    2016.05.29.b  May  2016  Unprovoked                 USA
# 59      2016.05.22  May  2016  Unprovoked                 USA
# 60    2016.05.21.b  May  2016  Unprovoked                 USA
# 61    2016.05.21.a  May  2016  Unprovoked                 USA
# ...

# %% [markdown]
# RECUENTO Y LIMPIEZA DE LA VARIABLE AGE

# %%
SharknoNa1['Age'].value_counts()
# Out:
# Unknown    201
# 13          18
# 14          14
# 10          12
# 15          12
# 12          11
# 20          11
# 9           10
# 19          10
# 21           9
# 22           9
# 17           9
# 34           9
# 29           8
# 11           8
# 38           8
# 30           7
# 7            7
# 60           7
# 18           6
# 42           6
# 35           6
# 23           5
# 44           5
# 28           5
# 37           5
# 40           5
# 41           5
# 45           4
# 6            4
#           ...
# 26           4
# 50           4
# 24           4
# 36           4
# 70           3
# 58           3
# 51           3
# 8            3
# 48           3
# 56           3
# 43           3
# 27           2
# 55           2
# 32           2
# 65           2
# 52           2
# 57           2
# 59           2
# 25           2
# 33           1
# 69           1
# 46           1
# 53           1
# 54           1
# 61           1
# 31           1
# 77           1
# ...

# %%
def findage (t):
    
    t = str(t)
    b = re.findall ('\d+', t)
    
    if len(b) == 1:
        return b[0]
    else:
        return 'Unknown'

# %%
SharknoNa1['Age']= SharknoNa1['Age'].apply(findage)

# %% [markdown]
# RECUENTO Y LIMPIEZA DE LA VARIABLE SEX

# %%
SharknoNa1['Sex '].value_counts()
# Out:
# F          363
# Unknown    147
# M            2
# Name: Sex , dtype: int64

# %%
print(set(SharknoNa1['Sex ']))
# Out:
# {'Unknown', 'F', 'M '}

# %%
SharknoNa1['Sex '].value_counts()
# Out:
# F          363
# Unknown    147
# M            2
# Name: Sex , dtype: int64

# %%
SharknoNa1=SharknoNa1[SharknoNa['Sex ']!='lli']
# Out:
# /home/javier/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
SharknoNa1=SharknoNa1[SharknoNa['Sex ']!='M']
# Out:
# /home/javier/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# RECUENTO DE LA VARIABLE ACTIVITY

# %%
SharknoNa1['Activity'].value_counts()
# Out:
# Swimming                                                            93
# Surfing                                                             61
# Unknown                                                             48
# Wading                                                              41
# Snorkeling                                                          33
# Fishing                                                             30
# Standing                                                            15
# Spearfishing                                                        11
# Diving                                                              10
# Boogie boarding                                                      9
# Scuba diving                                                         7
# Boogie Boarding                                                      6
# Walking                                                              6
# ...

# %% [markdown]
# RECUENTO DE LA VARIABLE YEAR

# %%
SharknoNa1['Year'].value_counts()
# Out:
# 2007    34
# 2014    33
# 2015    29
# 2012    26
# 2005    25
# 2000    23
# 2006    22
# 2004    22
# 2010    22
# 2009    22
# 2016    21
# 2013    20
# 1993    20
# 2001    20
# 2011    19
# 2008    19
# 1996    17
# 2003    17
# 1994    16
# 2002    15
# 1999    14
# 1995    14
# 1997    11
# 1992    10
# 1998     9
# 1991     7
# 1990     5
# Name: Year, dtype: int64

# %%
SharknoNa2 = SharknoNa1

# %%
SharknoNa2.to_csv('./Database1.csv')

# %% [markdown]
# DATAFRAME FINAL

# %%
display(SharknoNa2)
# Out:
#        Case Number Date  Year        Type             Country  \
# 5     2016.09.15.R  Sep  2016        Boat           AUSTRALIA
# 7       2016.09.07  Sep  2016  Unprovoked                 USA
# 9     2016.09.05.b  Sep  2016  Unprovoked                 USA
# 29      2016.07.17  Jul  2016        Boat                 USA
# 30    2016.07.16.b  Jul  2016  Unprovoked                 USA
# 31    2016.07.16.a  Jul  2016  Unprovoked                 USA
# 34    2016.07.08.R  Jul  2016  Unprovoked               SPAIN
# 38      2016.07.06  Jul  2016  Unprovoked                 USA
# 48      2016.06.14  Jun  2016  Unprovoked                 USA
# 52    2016.06.05.a  Jun  2016  Unprovoked           AUSTRALIA
# 57    2016.05.29.b  May  2016  Unprovoked                 USA
# 59      2016.05.22  May  2016  Unprovoked                 USA
# 60    2016.05.21.b  May  2016  Unprovoked                 USA
# 61    2016.05.21.a  May  2016  Unprovoked                 USA
# ...
