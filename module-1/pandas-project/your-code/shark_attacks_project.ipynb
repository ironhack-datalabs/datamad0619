# %%
import pandas as pd
import os
from re import sub
import numpy
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1437-2603e7045395> in <module>
#       3 from re import sub
#       4 import numpy
# ----> 5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
data = pd.read_csv('attacks.csv', encoding='latin-1')
data

# %%
#PRIMER VISTAZO A LOS DATOS
#Después de haber importado la base de datos, lo primero que hago es buscar información 
#sobre el dataframe (¿Qué columnas la componen?, ¿Cuántos datos continenen?, 
#¿Hay alguna columna que pueda borrar?, etc.)

# %%
#Cuantas líneas y columnas
data.shape
# Out:
# (25723, 24)

# %%
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
data.dtypes.head()
# Out:
# Case Number     object
# Date            object
# Year           float64
# Type            object
# Country         object
# dtype: object

# %%
#Creo una copia de la base de datos original, para trabajar desde esa copia
tiburon = data
tiburon
# Out:
#         Case Number                  Date    Year          Type       Country  \
# 0        2018.06.25           25-Jun-2018  2018.0       Boating           USA
# 1        2018.06.18           18-Jun-2018  2018.0    Unprovoked           USA
# 2        2018.06.09           09-Jun-2018  2018.0       Invalid           USA
# 3        2018.06.08           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4        2018.06.04           04-Jun-2018  2018.0      Provoked        MEXICO
# 5      2018.06.03.b           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6      2018.06.03.a           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7        2018.05.27           27-May-2018  2018.0    Unprovoked           USA
# 8      2018.05.26.b           26-May-2018  2018.0    Unprovoked           USA
# 9      2018.05.26.a           26-May-2018  2018.0    Unprovoked           USA
# 10       2018.05.24           24-May-2018  2018.0      Provoked     AUSTRALIA
# 11       2018.05.21           21-May-2018  2018.0    Unprovoked           USA
# 12     2018.05.13.b           13-May-2018  2018.0    Unprovoked           USA
# 13     2018.05.13.a           13-May-2018  2018.0       Invalid       ENGLAND
# 14       2018.05.00              May 2018  2018.0      Provoked     AUSTRALIA
# 15       2018.05.12           12-May-2018  2018.0    Unprovoked  SOUTH AFRICA
# 16       2018.05.09           09-May-2018  2018.0  Questionable     AUSTRALIA
# 17     2018.04.30.R  Reported 30-Apr-2018  2018.0    Unprovoked      THAILAND
# 18     2018.04.28.b           28-Apr-2018  2018.0    Unprovoked    COSTA RICA
# 19     2018.04.28.a           28-Apr-2018  2018.0    Unprovoked     AUSTRALIA
# 20     2018.04.25.b           25-Apr-2018  2018.0  Questionable     AUSTRALIA
# 21     2018.04.25.a           25-Apr-2018  2018.0    Unprovoked     AUSTRALIA
# 22       2018.04.24           24-Apr-2018  2018.0    Unprovoked     AUSTRALIA
# 23       2018.04.23           23-Apr-2018  2018.0    Unprovoked      MALDIVES
# 24       2018.04.22           22-Apr-2018  2018.0    Unprovoked  SOUTH AFRICA
# 25       2018.04.19           19-Apr-2018  2018.0    Unprovoked           USA
# 26     2018.04.15.d           15-Apr-2018  2018.0    Unprovoked      THAILAND
# 27     2018.04.15.c           15-Apr-2018  2018.0    Unprovoked        BRAZIL
# 28     2018.04.15.b           15-Apr-2018  2018.0    Unprovoked     AUSTRALIA
# 29     2018.04.15.a           15-Apr-2018  2018.0    Unprovoked     AUSTRALIA
# ...             ...                   ...     ...           ...           ...
# 25693           NaN                   NaN     NaN           NaN           NaN
# 25694           NaN                   NaN     NaN           NaN           NaN
# 25695           NaN                   NaN     NaN           NaN           NaN
# 25696           NaN                   NaN     NaN           NaN           NaN
# 25697           NaN                   NaN     NaN           NaN           NaN
# 25698           NaN                   NaN     NaN           NaN           NaN
# 25699           NaN                   NaN     NaN           NaN           NaN
# 25700           NaN                   NaN     NaN           NaN           NaN
# 25701           NaN                   NaN     NaN           NaN           NaN
# 25702           NaN                   NaN     NaN           NaN           NaN
# 25703           NaN                   NaN     NaN           NaN           NaN
# 25704           NaN                   NaN     NaN           NaN           NaN
# 25705           NaN                   NaN     NaN           NaN           NaN
# 25706           NaN                   NaN     NaN           NaN           NaN
# 25707           NaN                   NaN     NaN           NaN           NaN
# 25708           NaN                   NaN     NaN           NaN           NaN
# 25709           NaN                   NaN     NaN           NaN           NaN
# 25710           NaN                   NaN     NaN           NaN           NaN
# 25711           NaN                   NaN     NaN           NaN           NaN
# 25712           NaN                   NaN     NaN           NaN           NaN
# 25713           NaN                   NaN     NaN           NaN           NaN
# 25714           NaN                   NaN     NaN           NaN           NaN
# 25715           NaN                   NaN     NaN           NaN           NaN
# 25716           NaN                   NaN     NaN           NaN           NaN
# 25717           NaN                   NaN     NaN           NaN           NaN
# 25718           NaN                   NaN     NaN           NaN           NaN
# 25719           NaN                   NaN     NaN           NaN           NaN
# 25720           NaN                   NaN     NaN           NaN           NaN
# 25721           NaN                   NaN     NaN           NaN           NaN
# 25722            xx                   NaN     NaN           NaN           NaN
#
#                         Area  \
# 0                 California
# 1                    Georgia
# 2                     Hawaii
# 3            New South Wales
# 4                     Colima
# 5            New South Wales
# 6                 Pernambuco
# 7                    Florida
# 8                    Florida
# 9                    Florida
# 10                Queensland
# 11            South Carolina
# 12            South Carolina
# 13                  Cornwall
# 14         Westerm Australia
# 15     Eastern Cape Province
# 16           New South Wales
# 17                   Hua Hin
# 18              Cocos Island
# 19         Western Australia
# 20           New South Wales
# 21         Western Australia
# 22         Western Australia
# 23         Alifu Alifu Atoll
# 24     Western Cape Province
# 25                    Hawaii
# 26                   Hua Hin
# 27                Pernambuco
# 28         Western Australia
# 29         Western Australia
# ...                      ...
# 25693                    NaN
# 25694                    NaN
# 25695                    NaN
# 25696                    NaN
# 25697                    NaN
# 25698                    NaN
# 25699                    NaN
# 25700                    NaN
# 25701                    NaN
# 25702                    NaN
# 25703                    NaN
# 25704                    NaN
# 25705                    NaN
# 25706                    NaN
# 25707                    NaN
# 25708                    NaN
# 25709                    NaN
# 25710                    NaN
# 25711                    NaN
# 25712                    NaN
# 25713                    NaN
# 25714                    NaN
# 25715                    NaN
# 25716                    NaN
# 25717                    NaN
# 25718                    NaN
# 25719                    NaN
# 25720                    NaN
# 25721                    NaN
# 25722                    NaN
#
#                                                 Location         Activity  \
# 0                            Oceanside, San Diego County         Paddling
# 1                         St. Simon Island, Glynn County         Standing
# 2                                           Habush, Oahu          Surfing
# 3                                     Arrawarra Headland          Surfing
# 4                                               La Ticla      Free diving
# 5                                     Flat Rock, Ballina     Kite surfing
# 6                                  Piedade Beach, Recife         Swimming
# 7      Lighhouse Point Park, Ponce Inlet, Volusia County          Fishing
# 8                           Cocoa Beach, Brevard  County          Walking
# 9                          Daytona Beach, Volusia County         Standing
# 10                                       Cairns Aquarium   Feeding sharks
# 11                     Isle of Palms,  Charleston County  Boogie boarding
# 12                   Hilton Head Island, Beaufort County         Swimming
# 13                                        Off Land's End          Fishing
# 14                                            Dugong Bay   Feeding sharks
# 15                             Nahoon Beach, East London          Surfing
# 16                                Sharpes Beach, Ballina          Surfing
# 17                                         Sai Noi Beach         Swimming
# 18                                             Manuelita     Scuba diving
# 19                                          Gearys Beach          Surfing
# 20                                           Lennox Head          Surfing
# 21                               Surfers Point, Prevelly          Surfing
# 22                                South Point, Gracetown          Surfing
# 23                                             Madoogali          Fishing
# 24                        Robberg Beach, Plettenberg Bay    Paddle-skiing
# 25                Shipwrecks Beach, Keoneloa Bay, Kauai    Body boarding
# 26                                         Sai Noi Beach         Swimming
# 27                                               Piedade         Swimming
# 28                      Lefthanders, Margaret River Area          Surfing
# 29                     Cobblestones, Margaret River Area          Surfing
# ...                                                  ...              ...
# 25693                                                NaN              NaN
# 25694                                                NaN              NaN
# 25695                                                NaN              NaN
# 25696                                                NaN              NaN
# 25697                                                NaN              NaN
# 25698                                                NaN              NaN
# 25699                                                NaN              NaN
# 25700                                                NaN              NaN
# 25701                                                NaN              NaN
# 25702                                                NaN              NaN
# 25703                                                NaN              NaN
# 25704                                                NaN              NaN
# 25705                                                NaN              NaN
# 25706                                                NaN              NaN
# 25707                                                NaN              NaN
# 25708                                                NaN              NaN
# 25709                                                NaN              NaN
# 25710                                                NaN              NaN
# 25711                                                NaN              NaN
# 25712                                                NaN              NaN
# 25713                                                NaN              NaN
# 25714                                                NaN              NaN
# 25715                                                NaN              NaN
# 25716                                                NaN              NaN
# 25717                                                NaN              NaN
# 25718                                                NaN              NaN
# 25719                                                NaN              NaN
# 25720                                                NaN              NaN
# 25721                                                NaN              NaN
# 25722                                                NaN              NaN
#
#                          Name Sex   ...                         Species   \
# 0                 Julie Wolfe    F  ...                      White shark
# 1             Adyson McNeely     F  ...                              NaN
# 2                 John Denges    M  ...                              NaN
# 3                        male    M  ...                        2 m shark
# 4              Gustavo Ramos     M  ...                  Tiger shark, 3m
# 5                     Chris
#     M  ...                              NaN
# 6      Jose Ernesto da Silva     M  ...                      Tiger shark
# 7                        male    M  ...                  Lemon shark, 3'
# 8                   Cody High    M  ...                   Bull shark, 6'
# 9                        male    M  ...                              NaN
# 10                       male    M  ...                  Grey reef shark
# 11               Trey de Boer    M  ...                              NaN
# 12                Jei Turrell    M  ...                              NaN
# 13               Max Berryman    M  ...                 Invalid incident
# 14            Melisa Brunning    F  ...            Tawny nurse shark, 2m
# 15                       male    M  ...                              NaN
# 16                       male    M  ...  Shark involvement not confirmed
# 17                     female    M  ...                              NaN
# 18                       male    M  ...                      Tiger shark
# 19                Adam Murray    M  ...                              NaN
# 20                Matthew Lee    M  ...                     Questionable
# 21                  Rob Bruce    M  ...                        3 m shark
# 22               Nathan Burch    M  ...               White shark, 3.5 m
# 23              Ahmed Rasheed    M  ...                      Tiger shark
# 24                       male    M  ...               White shark, 2.5 m
# 25           Dylan McWilliams    M  ...                         6' shark
# 26           Werner Danielsen    M  ...              Juvenile bull shark
# 27              Pablo de Melo    M  ...                              NaN
# 28             Jason Longrass    M  ...                              NaN
# 29       Alejandro Travaglini    M  ...                              NaN
# ...                       ...  ...  ...                              ...
# 25693                     NaN  NaN  ...                              NaN
# 25694                     NaN  NaN  ...                              NaN
# 25695                     NaN  NaN  ...                              NaN
# 25696                     NaN  NaN  ...                              NaN
# 25697                     NaN  NaN  ...                              NaN
# 25698                     NaN  NaN  ...                              NaN
# 25699                     NaN  NaN  ...                              NaN
# 25700                     NaN  NaN  ...                              NaN
# 25701                     NaN  NaN  ...                              NaN
# 25702                     NaN  NaN  ...                              NaN
# 25703                     NaN  NaN  ...                              NaN
# 25704                     NaN  NaN  ...                              NaN
# 25705                     NaN  NaN  ...                              NaN
# 25706                     NaN  NaN  ...                              NaN
# 25707                     NaN  NaN  ...                              NaN
# 25708                     NaN  NaN  ...                              NaN
# 25709                     NaN  NaN  ...                              NaN
# 25710                     NaN  NaN  ...                              NaN
# 25711                     NaN  NaN  ...                              NaN
# 25712                     NaN  NaN  ...                              NaN
# 25713                     NaN  NaN  ...                              NaN
# 25714                     NaN  NaN  ...                              NaN
# 25715                     NaN  NaN  ...                              NaN
# 25716                     NaN  NaN  ...                              NaN
# 25717                     NaN  NaN  ...                              NaN
# 25718                     NaN  NaN  ...                              NaN
# 25719                     NaN  NaN  ...                              NaN
# 25720                     NaN  NaN  ...                              NaN
# 25721                     NaN  NaN  ...                              NaN
# 25722                     NaN  NaN  ...                              NaN
#
#                                   Investigator or Source  \
# 0                                       R. Collier, GSAF
# 1                         K.McMurray, TrackingSharks.com
# 2                         K.McMurray, TrackingSharks.com
# 3                                         B. Myatt, GSAF
# 4                                              A .Kipper
# 5                              Daily Telegraph, 6/4/2018
# 6                         Diario de Pernambuco, 6/4/2018
# 7                        K. McMurray, TrackingSharks.com
# 8                         K.McMurray, TrackingSharks.com
# 9                       K. McMurray, Tracking Sharks.com
# 10                                ABC.net.au ,05/24/2018
# 11                                     C. Creswell, GSAF
# 12     C. Creswell, GSAF & K. McMurray TrackingSharks...
# 13                       K. McMurray, TrackingSharks.com
# 14                                  Perth Now, 6/30/2018
# 15                     B.Jacob, Dispatch Live, 5/12/2018
# 16                                        B. Myatt, GSAF
# 17                       K. McMurray, TrackingSharks.com
# 18                            Costa Rica Star. 4/28/2018
# 19                                        B. Myatt, GSAF
# 20                                        B. Myatt, GSAF
# 21                                         B.Myatt, GSAF
# 22                                        B. Myatt, GSAF
# 23                       K. McMurray, TrackingSharks.com
# 24                         Africa News Agency, 4/22/2018
# 25                          The Garden Island, 4/19/2018
# 26                              Straits Times, 4/16/2018
# 27                                      Globo, 4/16/2018
# 28                                         B.Myatt, GSAF
# 29                                         B.Myatt, GSAF
# ...                                                  ...
# 25693                                                NaN
# 25694                                                NaN
# 25695                                                NaN
# 25696                                                NaN
# 25697                                                NaN
# 25698                                                NaN
# 25699                                                NaN
# 25700                                                NaN
# 25701                                                NaN
# 25702                                                NaN
# 25703                                                NaN
# 25704                                                NaN
# 25705                                                NaN
# 25706                                                NaN
# 25707                                                NaN
# 25708                                                NaN
# 25709                                                NaN
# 25710                                                NaN
# 25711                                                NaN
# 25712                                                NaN
# 25713                                                NaN
# 25714                                                NaN
# 25715                                                NaN
# 25716                                                NaN
# 25717                                                NaN
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# 5          2018.06.03.b-FlatRock.pdf
# 6           2018.06.03.a-daSilva.pdf
# 7               2018.05.27-Ponce.pdf
# 8              2018.05.26.b-High.pdf
# 9      2018.05.26.a-DaytonaBeach.pdf
# 10     2018.05.24-CairnsAquarium.pdf
# 11             2018.05.21-deBoer.pdf
# 12          2018.05.13.b-Turrell.pdf
# 13         2018.05.13.a-Berryman.pdf
# 14           2018.05.00-Brunning.pdf
# 15         2018.05.12-EastLondon.pdf
# 16       2018.05.09-SharpesBeach.pdf
# 17         2018.04.30.R-Thailand.pdf
# 18        2018.04.28.b-CostaRica.pdf
# 19           2018.04.28.a-Murray.pdf
# 20              2018.04.25.b-Lee.pdf
# 21            2018.04.25.a-Bruce.pdf
# 22              2018.04.24-Burch.pdf
# 23           2018.04.23-Maldives.pdf
# 24     2018.04.22-PlettenbergBay.pdf
# 25         2018.04.19-McWilliams.pdf
# 26         2018.04.15.d-Thailand.pdf
# 27           2018.04.15.c-deMelo.pdf
# 28         2018.04.15.b-Longrass.pdf
# 29       2018.04.15.a-Travaglini.pdf
# ...                              ...
# 25693                            NaN
# 25694                            NaN
# 25695                            NaN
# 25696                            NaN
# 25697                            NaN
# 25698                            NaN
# 25699                            NaN
# 25700                            NaN
# 25701                            NaN
# 25702                            NaN
# 25703                            NaN
# 25704                            NaN
# 25705                            NaN
# 25706                            NaN
# 25707                            NaN
# 25708                            NaN
# 25709                            NaN
# 25710                            NaN
# 25711                            NaN
# 25712                            NaN
# 25713                            NaN
# 25714                            NaN
# 25715                            NaN
# 25716                            NaN
# 25717                            NaN
# 25718                            NaN
# 25719                            NaN
# 25720                            NaN
# 25721                            NaN
# 25722                            NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# 5      http://sharkattackfile.net/spreadsheets/pdf_di...
# 6      http://sharkattackfile.net/spreadsheets/pdf_di...
# 7      http://sharkattackfile.net/spreadsheets/pdf_di...
# 8      http://sharkattackfile.net/spreadsheets/pdf_di...
# 9      http://sharkattackfile.net/spreadsheets/pdf_di...
# 10     http://sharkattackfile.net/spreadsheets/pdf_di...
# 11     http://sharkattackfile.net/spreadsheets/pdf_di...
# 12     http://sharkattackfile.net/spreadsheets/pdf_di...
# 13     http://sharkattackfile.net/spreadsheets/pdf_di...
# 14     http://sharkattackfile.net/spreadsheets/pdf_di...
# 15     http://sharkattackfile.net/spreadsheets/pdf_di...
# 16     http://sharkattackfile.net/spreadsheets/pdf_di...
# 17     http://sharkattackfile.net/spreadsheets/pdf_di...
# 18     http://sharkattackfile.net/spreadsheets/pdf_di...
# 19     http://sharkattackfile.net/spreadsheets/pdf_di...
# 20     http://sharkattackfile.net/spreadsheets/pdf_di...
# 21     http://sharkattackfile.net/spreadsheets/pdf_di...
# 22     http://sharkattackfile.net/spreadsheets/pdf_di...
# 23     http://sharkattackfile.net/spreadsheets/pdf_di...
# 24     http://sharkattackfile.net/spreadsheets/pdf_di...
# 25     http://sharkattackfile.net/spreadsheets/pdf_di...
# 26     http://sharkattackfile.net/spreadsheets/pdf_di...
# 27     http://sharkattackfile.net/spreadsheets/pdf_di...
# 28     http://sharkattackfile.net/spreadsheets/pdf_di...
# 29     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25693                                                NaN
# 25694                                                NaN
# 25695                                                NaN
# 25696                                                NaN
# 25697                                                NaN
# 25698                                                NaN
# 25699                                                NaN
# 25700                                                NaN
# 25701                                                NaN
# 25702                                                NaN
# 25703                                                NaN
# 25704                                                NaN
# 25705                                                NaN
# 25706                                                NaN
# 25707                                                NaN
# 25708                                                NaN
# 25709                                                NaN
# 25710                                                NaN
# 25711                                                NaN
# 25712                                                NaN
# 25713                                                NaN
# 25714                                                NaN
# 25715                                                NaN
# 25716                                                NaN
# 25717                                                NaN
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# 5      http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.03.b
# 6      http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.03.a
# 7      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.27
# 8      http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.26.b
# 9      http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.26.a
# 10     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.24
# 11     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.21
# 12     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.13.b
# 13     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.13.a
# 14     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.00
# 15     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.12
# 16     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.09
# 17     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.30.R
# 18     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.28.b
# 19     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.28.a
# 20     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.25.b
# 21     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.25.a
# 22     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.04.24
# 23     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.04.23
# 24     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.04.22
# 25     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.04.19
# 26     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.15.d
# 27     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.15.c
# 28     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.15.b
# 29     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.15.a
# ...                                                  ...           ...
# 25693                                                NaN           NaN
# 25694                                                NaN           NaN
# 25695                                                NaN           NaN
# 25696                                                NaN           NaN
# 25697                                                NaN           NaN
# 25698                                                NaN           NaN
# 25699                                                NaN           NaN
# 25700                                                NaN           NaN
# 25701                                                NaN           NaN
# 25702                                                NaN           NaN
# 25703                                                NaN           NaN
# 25704                                                NaN           NaN
# 25705                                                NaN           NaN
# 25706                                                NaN           NaN
# 25707                                                NaN           NaN
# 25708                                                NaN           NaN
# 25709                                                NaN           NaN
# 25710                                                NaN           NaN
# 25711                                                NaN           NaN
# 25712                                                NaN           NaN
# 25713                                                NaN           NaN
# 25714                                                NaN           NaN
# 25715                                                NaN           NaN
# 25716                                                NaN           NaN
# 25717                                                NaN           NaN
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# 5      2018.06.03.b         6298.0         NaN         NaN
# 6      2018.06.03.a         6297.0         NaN         NaN
# 7        2018.05.27         6296.0         NaN         NaN
# 8      2018.05.26.b         6295.0         NaN         NaN
# 9      2018.05.26.a         6294.0         NaN         NaN
# 10       2018.05.24         6293.0         NaN         NaN
# 11       2018.05.21         6292.0         NaN         NaN
# 12     2018.05.13.b         6291.0         NaN         NaN
# 13     2018.05.13.a         6290.0         NaN         NaN
# 14       2018.05.00         6289.0         NaN         NaN
# 15       2018.05.12         6288.0         NaN         NaN
# 16       2018.05.09         6287.0         NaN         NaN
# 17     2018.04.30.R         6286.0         NaN         NaN
# 18     2018.04.28.b         6285.0         NaN         NaN
# 19     2018.04.28.a         6284.0         NaN         NaN
# 20     2018.04.25.b         6283.0         NaN         NaN
# 21     2018.04.25.a         6282.0         NaN         NaN
# 22       2018.04.24         6281.0         NaN         NaN
# 23       2018.04.23         6280.0         NaN         NaN
# 24       2018.04.22         6279.0         NaN         NaN
# 25       2018.04.19         6278.0         NaN         NaN
# 26     2018.04.15.d         6277.0         NaN         NaN
# 27     2018.04.15.c         6276.0         NaN         NaN
# 28     2018.04.15.b         6275.0         NaN         NaN
# 29     2018.04.15.a         6274.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25693           NaN            NaN         NaN         NaN
# 25694           NaN            NaN         NaN         NaN
# 25695           NaN            NaN         NaN         NaN
# 25696           NaN            NaN         NaN         NaN
# 25697           NaN            NaN         NaN         NaN
# 25698           NaN            NaN         NaN         NaN
# 25699           NaN            NaN         NaN         NaN
# 25700           NaN            NaN         NaN         NaN
# 25701           NaN            NaN         NaN         NaN
# 25702           NaN            NaN         NaN         NaN
# 25703           NaN            NaN         NaN         NaN
# 25704           NaN            NaN         NaN         NaN
# 25705           NaN            NaN         NaN         NaN
# 25706           NaN            NaN         NaN         NaN
# 25707           NaN            NaN         NaN         NaN
# 25708           NaN            NaN         NaN         NaN
# 25709           NaN            NaN         NaN         NaN
# 25710           NaN            NaN         NaN         NaN
# 25711           NaN            NaN         NaN         NaN
# 25712           NaN            NaN         NaN         NaN
# 25713           NaN            NaN         NaN         NaN
# 25714           NaN            NaN         NaN         NaN
# 25715           NaN            NaN         NaN         NaN
# 25716           NaN            NaN         NaN         NaN
# 25717           NaN            NaN         NaN         NaN
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %%
#Voy a mirar cuantos nulos tengo en cada variable para ver si puedo borrar alguna columna
#tiburon.isnull().sum()

# %%
#Voy a borrar estas columnas que tienen información incomprensible
#tiburon_quitar = tiburon.columns(['Date','Type','Country','Area','Location','Activity','Name','Age','Injury','Time','Species ','Investigator or Source','pdf','href formula','href','Case Number.1','Case Number.2','original order','Unnamed: 22','Unnamed: 23'], axis=0)
#tiburon = tiburon_quitar
#tiburon

col_malas = tiburon.drop(columns = ['Date','Type','Country','Area','Location','Activity','Name','Age','Injury','Time','Species ','Investigator or Source','pdf','href formula','href','Case Number.1','Case Number.2','original order','Unnamed: 22','Unnamed: 23'], axis=1)
tiburon = col_malas
tiburon
#col_malas2 = tiburon.drop(columns = ['Area','Location','Activity','Name'], axis=1)
#tiburon = col_malas2
#tiburon
#col_malas3 = tiburon.drop(columns = ['Date','Type','Country'], axis=1)
#tiburon = col_malas3
#tiburon
# Out:
#         Case Number    Year Sex  Fatal (Y/N)
# 0        2018.06.25  2018.0    F           N
# 1        2018.06.18  2018.0    F           N
# 2        2018.06.09  2018.0    M           N
# 3        2018.06.08  2018.0    M           N
# 4        2018.06.04  2018.0    M           N
# 5      2018.06.03.b  2018.0    M           N
# 6      2018.06.03.a  2018.0    M           Y
# 7        2018.05.27  2018.0    M           N
# 8      2018.05.26.b  2018.0    M           N
# 9      2018.05.26.a  2018.0    M           N
# 10       2018.05.24  2018.0    M           N
# 11       2018.05.21  2018.0    M           N
# 12     2018.05.13.b  2018.0    M           N
# 13     2018.05.13.a  2018.0    M           N
# 14       2018.05.00  2018.0    F           N
# 15       2018.05.12  2018.0    M           N
# 16       2018.05.09  2018.0    M           N
# 17     2018.04.30.R  2018.0    M           N
# 18     2018.04.28.b  2018.0    M           N
# 19     2018.04.28.a  2018.0    M           N
# 20     2018.04.25.b  2018.0    M           N
# 21     2018.04.25.a  2018.0    M           N
# 22       2018.04.24  2018.0    M           N
# 23       2018.04.23  2018.0    M           N
# 24       2018.04.22  2018.0    M           N
# 25       2018.04.19  2018.0    M           N
# 26     2018.04.15.d  2018.0    M           N
# 27     2018.04.15.c  2018.0    M         NaN
# 28     2018.04.15.b  2018.0    M           N
# 29     2018.04.15.a  2018.0    M           N
# ...             ...     ...  ...         ...
# 25693           NaN     NaN  NaN         NaN
# 25694           NaN     NaN  NaN         NaN
# 25695           NaN     NaN  NaN         NaN
# 25696           NaN     NaN  NaN         NaN
# 25697           NaN     NaN  NaN         NaN
# 25698           NaN     NaN  NaN         NaN
# 25699           NaN     NaN  NaN         NaN
# 25700           NaN     NaN  NaN         NaN
# 25701           NaN     NaN  NaN         NaN
# 25702           NaN     NaN  NaN         NaN
# 25703           NaN     NaN  NaN         NaN
# 25704           NaN     NaN  NaN         NaN
# 25705           NaN     NaN  NaN         NaN
# 25706           NaN     NaN  NaN         NaN
# 25707           NaN     NaN  NaN         NaN
# 25708           NaN     NaN  NaN         NaN
# 25709           NaN     NaN  NaN         NaN
# 25710           NaN     NaN  NaN         NaN
# 25711           NaN     NaN  NaN         NaN
# 25712           NaN     NaN  NaN         NaN
# 25713           NaN     NaN  NaN         NaN
# 25714           NaN     NaN  NaN         NaN
# 25715           NaN     NaN  NaN         NaN
# 25716           NaN     NaN  NaN         NaN
# 25717           NaN     NaN  NaN         NaN
# 25718           NaN     NaN  NaN         NaN
# 25719           NaN     NaN  NaN         NaN
# 25720           NaN     NaN  NaN         NaN
# 25721           NaN     NaN  NaN         NaN
# 25722            xx     NaN  NaN         NaN
#
# [25723 rows x 4 columns]

# %%
#HIPÓTESIS:

#Después de haber observado el DataFrame y el tipo de información que la integra, 
#considero que sería interesante realizar mi trabajo con respecto a la siguiente hipótesis:

#En los últimos años el número de ataques de tiburón tienen consecuencias menos importantes para sus víctimas. 
#Compararé los años 2000-2010 y los años 1950-1960, observando el número total de ataques así como su proporción.
#También quiero observar si hay más mujeres víctimas en los años 2000 que en los años 1950 (aunque no pueda
#mergear los datos con otro DataFrame que pueda demostrar la causalidad: creo que la emancipación 
#de las mujeres ha hecho que en los últimos años, ellas trabajen más fuera de casa 
#y que tengan más tiempo de ocio (en general, y por ende también en el mar).

# %%
#Voy a crear una función para conocer número de valores de todas las columnas:

# %%
def cls_counts(df):
    for col in df.columns:
        print("---%s---" %col)
        print(df[col].value_counts())

# %%
#Lo pruebo:
cls_counts(tiburon)
# Out:
# ---Case Number---
# 0                 2400
# 1983.06.15           2
# 1915.07.06.a.R       2
# 1990.05.10           2
# 2014.08.02           2
# 2006.09.02           2
# 1980.07.00           2
# 1913.08.27.R         2
# 1962.06.11.b         2
# 2013.10.05           2
# 1966.12.26           2
# 2009.12.18           2
# 2012.09.02.b         2
# 1920.00.00.b         2
# 1907.10.16.R         2
# 2005.04.06           2
# 1923.00.00.a         2
# 1932.04.16.a         1
# 1855.00.00           1
# 1931.06.13           1
# 1996.05.10           1
# 1928.08.24.R         1
# 1995.08.10.a         1
# 1936.06.06           1
# 1939.07.14           1
# 2000.09.00.b         1
# 1957.07.15           1
# 2010.10.02.a         1
# 1967.08.15           1
# 1924.03.24           1
#                   ...
# 2002.11.28.b         1
# 1960.01.30           1
# 1965.06.19           1
# ND.0009              1
# 2018.04.23           1
# 2017.05.12           1
# 1956.07.20           1
# 1960.10.02           1
# 1976.03.09           1
# 1995.09.13           1
# 1888.10.23.R         1
# 2018.01.12           1
# 1981.00.00.b         1
# 1961.05.15           1
# 2008.05.26           1
# 0077.00.00           1
# 1947.11.08.a         1
# 2004.02.29           1
# 1988.07.04.b         1
# 1959.02.01           1
# 1849.10.04           1
# 2000.10.14           1
# 2017.09.16.b         1
# 1996.09.01.a         1
# 2006.07.10           1
# 1945.09.19           1
# 1990.08.19.b         1
# 1865.00.00           1
# 1907.07.00           1
# 1996.01.14.b         1
# Name: Case Number, Length: 6287, dtype: int64
# ---Year---
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
# 0.0       125
# 2008.0    122
# 2013.0    122
# 2009.0    120
# 2012.0    117
# 2007.0    112
# 2006.0    103
# 2005.0    103
# 2010.0    101
# 2000.0     97
# 1959.0     93
# 1960.0     93
# 2003.0     92
# 2004.0     92
# 2001.0     92
# 2002.0     88
# 1962.0     86
# 1961.0     78
# 1995.0     76
# 1999.0     66
# 1964.0     66
# 1998.0     65
# 1963.0     61
# 1996.0     61
# 1966.0     58
#          ...
# 1784.0      1
# 1617.0      1
# 1764.0      1
# 1721.0      1
# 1792.0      1
# 1834.0      1
# 1841.0      1
# 1595.0      1
# 1755.0      1
# 1738.0      1
# 1807.0      1
# 1723.0      1
# 1804.0      1
# 1780.0      1
# 1801.0      1
# 1767.0      1
# 1815.0      1
# 1822.0      1
# 1818.0      1
# 1783.0      1
# 1797.0      1
# 1800.0      1
# 1771.0      1
# 1748.0      1
# 1555.0      1
# 1753.0      1
# 77.0        1
# 1785.0      1
# 1580.0      1
# 1543.0      1
# Name: Year, Length: 249, dtype: int64
# ---Sex ---
# M      5094
# F       637
# N         2
# M         2
# .         1
# lli       1
# Name: Sex , dtype: int64
# ---Fatal (Y/N)---
# N          4293
# Y          1388
# UNKNOWN      71
#  N            7
# y             1
# M             1
# N             1
# 2017          1
# Name: Fatal (Y/N), dtype: int64

# %%
#CASE NUMBER
#En primer lugar, quiero eliminar las filas duplicadas en la columna Case Number, 
#ya que cada fila debería tener un valor diferente:

# %%
var3 = tiburon['Case Number'] 
var3 = tiburon.drop_duplicates(subset=['Case Number'], keep='first')
tiburon['Case Number'] = var3
tiburon
# Out:
#         Case Number    Year Sex  Fatal (Y/N)
# 0        2018.06.25  2018.0    F           N
# 1        2018.06.18  2018.0    F           N
# 2        2018.06.09  2018.0    M           N
# 3        2018.06.08  2018.0    M           N
# 4        2018.06.04  2018.0    M           N
# 5      2018.06.03.b  2018.0    M           N
# 6      2018.06.03.a  2018.0    M           Y
# 7        2018.05.27  2018.0    M           N
# 8      2018.05.26.b  2018.0    M           N
# 9      2018.05.26.a  2018.0    M           N
# 10       2018.05.24  2018.0    M           N
# 11       2018.05.21  2018.0    M           N
# 12     2018.05.13.b  2018.0    M           N
# 13     2018.05.13.a  2018.0    M           N
# 14       2018.05.00  2018.0    F           N
# 15       2018.05.12  2018.0    M           N
# 16       2018.05.09  2018.0    M           N
# 17     2018.04.30.R  2018.0    M           N
# 18     2018.04.28.b  2018.0    M           N
# 19     2018.04.28.a  2018.0    M           N
# 20     2018.04.25.b  2018.0    M           N
# 21     2018.04.25.a  2018.0    M           N
# 22       2018.04.24  2018.0    M           N
# 23       2018.04.23  2018.0    M           N
# 24       2018.04.22  2018.0    M           N
# 25       2018.04.19  2018.0    M           N
# 26     2018.04.15.d  2018.0    M           N
# 27     2018.04.15.c  2018.0    M         NaN
# 28     2018.04.15.b  2018.0    M           N
# 29     2018.04.15.a  2018.0    M           N
# ...             ...     ...  ...         ...
# 25693           NaN     NaN  NaN         NaN
# 25694           NaN     NaN  NaN         NaN
# 25695           NaN     NaN  NaN         NaN
# 25696           NaN     NaN  NaN         NaN
# 25697           NaN     NaN  NaN         NaN
# 25698           NaN     NaN  NaN         NaN
# 25699           NaN     NaN  NaN         NaN
# 25700           NaN     NaN  NaN         NaN
# 25701           NaN     NaN  NaN         NaN
# 25702           NaN     NaN  NaN         NaN
# 25703           NaN     NaN  NaN         NaN
# 25704           NaN     NaN  NaN         NaN
# 25705           NaN     NaN  NaN         NaN
# 25706           NaN     NaN  NaN         NaN
# 25707           NaN     NaN  NaN         NaN
# 25708           NaN     NaN  NaN         NaN
# 25709           NaN     NaN  NaN         NaN
# 25710           NaN     NaN  NaN         NaN
# 25711           NaN     NaN  NaN         NaN
# 25712           NaN     NaN  NaN         NaN
# 25713           NaN     NaN  NaN         NaN
# 25714           NaN     NaN  NaN         NaN
# 25715           NaN     NaN  NaN         NaN
# 25716           NaN     NaN  NaN         NaN
# 25717           NaN     NaN  NaN         NaN
# 25718           NaN     NaN  NaN         NaN
# 25719           NaN     NaN  NaN         NaN
# 25720           NaN     NaN  NaN         NaN
# 25721           NaN     NaN  NaN         NaN
# 25722            xx     NaN  NaN         NaN
#
# [25723 rows x 4 columns]

# %%
#Conocer el número de filas después de haber borrado los duplicados:
tiburon.shape
# Out:
# (25723, 4)

# %%
#Ahora voy a trabajar con la columna Year:

# %%
#YEAR
tiburon["Year"].value_counts()

#Observo que los registros son float y que también hay valores inverosímiles.
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
# 0.0       125
# 2008.0    122
# 2013.0    122
# 2009.0    120
# 2012.0    117
# 2007.0    112
# 2006.0    103
# 2005.0    103
# 2010.0    101
# 2000.0     97
# 1959.0     93
# 1960.0     93
# 2003.0     92
# 2004.0     92
# 2001.0     92
# 2002.0     88
# 1962.0     86
# 1961.0     78
# 1995.0     76
# 1999.0     66
# 1964.0     66
# 1998.0     65
# 1963.0     61
# 1996.0     61
# 1966.0     58
#          ...
# 1784.0      1
# 1617.0      1
# 1764.0      1
# 1721.0      1
# 1792.0      1
# 1834.0      1
# 1841.0      1
# 1595.0      1
# 1755.0      1
# 1738.0      1
# 1807.0      1
# 1723.0      1
# 1804.0      1
# 1780.0      1
# 1801.0      1
# 1767.0      1
# 1815.0      1
# 1822.0      1
# 1818.0      1
# 1783.0      1
# 1797.0      1
# 1800.0      1
# 1771.0      1
# 1748.0      1
# 1555.0      1
# 1753.0      1
# 77.0        1
# 1785.0      1
# 1580.0      1
# 1543.0      1
# Name: Year, Length: 249, dtype: int64

# %%
#Voy a ponerle otro valor a los valores nulos y así poder cambiar el tipo de los registros de Year:
#var4 = tiburon.fillna(0)
#tiburon = var4
#tiburon

# %%
#Voy a cambiar el tipo de los registros de la columna Year para quitar el ".0" 
#de todos los valores, ahora que ya no tengo valores nulos:

var5 = tiburon["Year"].astype("object")
tiburon["Year"]= var5
tiburon
# Out:
#         Case Number  Year Sex  Fatal (Y/N)
# 0        2018.06.25  2018    F           N
# 1        2018.06.18  2018    F           N
# 2        2018.06.09  2018    M           N
# 3        2018.06.08  2018    M           N
# 4        2018.06.04  2018    M           N
# 5      2018.06.03.b  2018    M           N
# 6      2018.06.03.a  2018    M           Y
# 7        2018.05.27  2018    M           N
# 8      2018.05.26.b  2018    M           N
# 9      2018.05.26.a  2018    M           N
# 10       2018.05.24  2018    M           N
# 11       2018.05.21  2018    M           N
# 12     2018.05.13.b  2018    M           N
# 13     2018.05.13.a  2018    M           N
# 14       2018.05.00  2018    F           N
# 15       2018.05.12  2018    M           N
# 16       2018.05.09  2018    M           N
# 17     2018.04.30.R  2018    M           N
# 18     2018.04.28.b  2018    M           N
# 19     2018.04.28.a  2018    M           N
# 20     2018.04.25.b  2018    M           N
# 21     2018.04.25.a  2018    M           N
# 22       2018.04.24  2018    M           N
# 23       2018.04.23  2018    M           N
# 24       2018.04.22  2018    M           N
# 25       2018.04.19  2018    M           N
# 26     2018.04.15.d  2018    M           N
# 27     2018.04.15.c  2018    M         NaN
# 28     2018.04.15.b  2018    M           N
# 29     2018.04.15.a  2018    M           N
# ...             ...   ...  ...         ...
# 25693           NaN   NaN  NaN         NaN
# 25694           NaN   NaN  NaN         NaN
# 25695           NaN   NaN  NaN         NaN
# 25696           NaN   NaN  NaN         NaN
# 25697           NaN   NaN  NaN         NaN
# 25698           NaN   NaN  NaN         NaN
# 25699           NaN   NaN  NaN         NaN
# 25700           NaN   NaN  NaN         NaN
# 25701           NaN   NaN  NaN         NaN
# 25702           NaN   NaN  NaN         NaN
# 25703           NaN   NaN  NaN         NaN
# 25704           NaN   NaN  NaN         NaN
# 25705           NaN   NaN  NaN         NaN
# 25706           NaN   NaN  NaN         NaN
# 25707           NaN   NaN  NaN         NaN
# 25708           NaN   NaN  NaN         NaN
# 25709           NaN   NaN  NaN         NaN
# 25710           NaN   NaN  NaN         NaN
# 25711           NaN   NaN  NaN         NaN
# 25712           NaN   NaN  NaN         NaN
# 25713           NaN   NaN  NaN         NaN
# 25714           NaN   NaN  NaN         NaN
# 25715           NaN   NaN  NaN         NaN
# 25716           NaN   NaN  NaN         NaN
# 25717           NaN   NaN  NaN         NaN
# 25718           NaN   NaN  NaN         NaN
# 25719           NaN   NaN  NaN         NaN
# 25720           NaN   NaN  NaN         NaN
# 25721           NaN   NaN  NaN         NaN
# 25722            xx   NaN  NaN         NaN
#
# [25723 rows x 4 columns]

# %%
#No soy capaz de quitar los 0
var6 = tiburon.dropna(how = 'any')
tiburon = var6
tiburon

#Esto está bien:
#var7 = tiburon.loc[~(tiburon!=0).any(axis=1)]
#tiburon = var7
#tiburon
# Out:
#        Case Number  Year Sex  Fatal (Y/N)
# 0       2018.06.25  2018    F           N
# 1       2018.06.18  2018    F           N
# 2       2018.06.09  2018    M           N
# 3       2018.06.08  2018    M           N
# 4       2018.06.04  2018    M           N
# 5     2018.06.03.b  2018    M           N
# 6     2018.06.03.a  2018    M           Y
# 7       2018.05.27  2018    M           N
# 8     2018.05.26.b  2018    M           N
# 9     2018.05.26.a  2018    M           N
# 10      2018.05.24  2018    M           N
# 11      2018.05.21  2018    M           N
# 12    2018.05.13.b  2018    M           N
# 13    2018.05.13.a  2018    M           N
# 14      2018.05.00  2018    F           N
# 15      2018.05.12  2018    M           N
# 16      2018.05.09  2018    M           N
# 17    2018.04.30.R  2018    M           N
# 18    2018.04.28.b  2018    M           N
# 19    2018.04.28.a  2018    M           N
# 20    2018.04.25.b  2018    M           N
# 21    2018.04.25.a  2018    M           N
# 22      2018.04.24  2018    M           N
# 23      2018.04.23  2018    M           N
# 24      2018.04.22  2018    M           N
# 25      2018.04.19  2018    M           N
# 26    2018.04.15.d  2018    M           N
# 28    2018.04.15.b  2018    M           N
# 29    2018.04.15.a  2018    M           N
# 30      2018.04.14  2018    M           N
# ...            ...   ...  ...         ...
# 6270       ND.0033     0    M           N
# 6271       ND.0032     0    M           N
# 6272       ND.0031     0    M           N
# 6273       ND.0030     0    M           Y
# 6274       ND.0028     0    M           N
# 6275       ND.0027     0    M           N
# 6276       ND.0026     0    M           Y
# 6277       ND.0025     0    M     UNKNOWN
# 6279       ND.0023     0    F           N
# 6280       ND.0022     0    M           N
# 6281       ND.0021     0    M           Y
# 6282       ND.0020     0    M           Y
# 6283       ND.0019     0    M           N
# 6284       ND.0018     0    M           N
# 6285       ND.0017     0    M           Y
# 6286       ND.0016     0    M           Y
# 6288       ND.0014     0    M           N
# 6289       ND.0013     0    M           Y
# 6290       ND.0012     0    M           Y
# 6291       ND.0011     0    M           N
# 6292       ND.0010     0    F           N
# 6293       ND.0009     0    M           Y
# 6294       ND.0008     0    M           Y
# 6295       ND.0007     0    M           Y
# 6296       ND.0006     0    M           Y
# 6297       ND.0005     0    M           Y
# 6298       ND.0004     0    M           Y
# 6299       ND.0003     0    M           Y
# 6300       ND.0002     0    M           Y
# 6301       ND.0001     0    M           Y
#
# [5263 rows x 4 columns]

# %%
#data5 = data4[data4["Year"]!= 0].copy()
#ass1 = data4[data4["Year"]!= 0].copy()
#ass1
#data4["Year"] = ass1
#cls_counts(data4)

# %%
#Voy a borrar los registros que no contienen año o un año realista (por ejemplo, 5, 77), 
#ya que va a resultar imposible trabajar con ello.
#Podría basarme en los registros como Case Number, pero tampoco tengo la certeza de que esos datos estén bien, y el 
#número de datos no es mi significativo para el total de registros que contiene la columna Years.

#data4["Year"].replace([0, 5, 77],[1, 1, 1])
#data5["Year"] = data4["Year"]

# %%
#data6 = data5.drop([1],axis=0)
#data6
#data5["Year"] = data5.set_index("Year",inplace=True)
#data4.drop["Year"]([1, 0, 5, 77], axis=0)
#data5.drop([1], axis=0,inplace=True)

#data = data.set_index("Area")
#data = data.drop("Ireland", axis=0)

# %%
#ass2 = data4["Year"].drop < 1000

#data4["Year"] = ass2
#data4.head()

#cols_no_nulls = raw_df2.columns[raw_df2.isnull().sum() < 1000]
#data_clean = data_clean[data_clean["Months"] & data_clean["Year"] != 0].copy()

# %%
#FATAL
#tiburon["Fatal (Y/N)"].value_counts()

# %%
#var7 = data2.replace(['y', ' N','N ','M','2017',],['Y','N','N','N','UNKNOWN'])
#No entiendo porqué Year vuelve a ser un float
var7 = tiburon.replace("[^N]", "N")
tiburon = var7
tiburon
#data3["Fatal (Y/N)"].value_counts()
# Out:
#        Case Number    Year Sex  Fatal (Y/N)
# 0       2018.06.25  2018.0    F           N
# 1       2018.06.18  2018.0    F           N
# 2       2018.06.09  2018.0    M           N
# 3       2018.06.08  2018.0    M           N
# 4       2018.06.04  2018.0    M           N
# 5     2018.06.03.b  2018.0    M           N
# 6     2018.06.03.a  2018.0    M           Y
# 7       2018.05.27  2018.0    M           N
# 8     2018.05.26.b  2018.0    M           N
# 9     2018.05.26.a  2018.0    M           N
# 10      2018.05.24  2018.0    M           N
# 11      2018.05.21  2018.0    M           N
# 12    2018.05.13.b  2018.0    M           N
# 13    2018.05.13.a  2018.0    M           N
# 14      2018.05.00  2018.0    F           N
# 15      2018.05.12  2018.0    M           N
# 16      2018.05.09  2018.0    M           N
# 17    2018.04.30.R  2018.0    M           N
# 18    2018.04.28.b  2018.0    M           N
# 19    2018.04.28.a  2018.0    M           N
# 20    2018.04.25.b  2018.0    M           N
# 21    2018.04.25.a  2018.0    M           N
# 22      2018.04.24  2018.0    M           N
# 23      2018.04.23  2018.0    M           N
# 24      2018.04.22  2018.0    M           N
# 25      2018.04.19  2018.0    M           N
# 26    2018.04.15.d  2018.0    M           N
# 28    2018.04.15.b  2018.0    M           N
# 29    2018.04.15.a  2018.0    M           N
# 30      2018.04.14  2018.0    M           N
# ...            ...     ...  ...         ...
# 6270       ND.0033     0.0    M           N
# 6271       ND.0032     0.0    M           N
# 6272       ND.0031     0.0    M           N
# 6273       ND.0030     0.0    M           Y
# 6274       ND.0028     0.0    M           N
# 6275       ND.0027     0.0    M           N
# 6276       ND.0026     0.0    M           Y
# 6277       ND.0025     0.0    M     UNKNOWN
# 6279       ND.0023     0.0    F           N
# 6280       ND.0022     0.0    M           N
# 6281       ND.0021     0.0    M           Y
# 6282       ND.0020     0.0    M           Y
# 6283       ND.0019     0.0    M           N
# 6284       ND.0018     0.0    M           N
# 6285       ND.0017     0.0    M           Y
# 6286       ND.0016     0.0    M           Y
# 6288       ND.0014     0.0    M           N
# 6289       ND.0013     0.0    M           Y
# 6290       ND.0012     0.0    M           Y
# 6291       ND.0011     0.0    M           N
# 6292       ND.0010     0.0    F           N
# 6293       ND.0009     0.0    M           Y
# 6294       ND.0008     0.0    M           Y
# 6295       ND.0007     0.0    M           Y
# 6296       ND.0006     0.0    M           Y
# 6297       ND.0005     0.0    M           Y
# 6298       ND.0004     0.0    M           Y
# 6299       ND.0003     0.0    M           Y
# 6300       ND.0002     0.0    M           Y
# 6301       ND.0001     0.0    M           Y
#
# [5263 rows x 4 columns]

# %%
#No consigo hacer que el número de casos sea count
#tiburon['Case Number'] = [len(x) for x in tiburon ['Case number Count']]
#tiburon

# %%
#Después de haber limpiado un poco mis columnas, voy a agrupar las columnas que me interesan
#de manera a poder estudiarlas con mayor profundidad

# %%
#df_pivot = tiburon.pivot_table(values = 'len()', columns = 'Year','Fatal (Y/N)', index = ['Sex '])
#tiburon = df_pivot
#tiburon

# %%
#var8 = tiburon.query('1950 <= Year <= 2010')
#tiburon = var8
#tiburon
#var9 = tiburon.query('2000 <= Year <= 2010')
#tiburon = var9
#tiburon

# %%
print(tiburon.loc[(tiburon["Year"] > 1950) & (tiburon["Fatal (Y/N)"] == "Y") & (tiburon["Sex "] == "M"),:])
# Out:
#        Case Number    Year Sex  Fatal (Y/N)
# 6     2018.06.03.a  2018.0    M           Y
# 64      2017.11.04  2017.0    M           Y
# 91    2017.09.03.b  2017.0    M           Y
# 144     2017.05.06  2017.0    M           Y
# 149   2017.04.29.a  2017.0    M           Y
# 174     2017.02.21  2017.0    M           Y
# 221     2016.09.06  2016.0    M           Y
# 271     2016.05.31  2016.0    M           Y
# 299     2016.03.10  2016.0    M           Y
# 325     2015.12.19  2015.0    M           Y
# 385     2015.07.25  2015.0    M           Y
# 425     2015.05.09  2015.0    M           Y
# 434     2015.04.12  2015.0    M           Y
# 440     2015.03.21  2015.0    M           Y
# 448     2015.02.09  2015.0    M           Y
# 464   2014.12.29.a  2014.0    M           Y
# 470     2014.12.15  2014.0    M           Y
# 473     2014.11.20  2014.0    M           Y
# 500     2014.09.09  2014.0    M           Y
# 571   2014.03.22.b  2014.0    M           Y
# 582     2014.02.08  2014.0    M           Y
# 596     2013.12.02  2013.0    M           Y
# 597     2013.11.30  2013.0    M           Y
# 599   2013.11.23.a  2013.0    M           Y
# 613     2013.10.11  2013.0    M           Y
# 655     2013.07.14  2013.0    M           Y
# 673   2013.05.23.b  2013.0    M           Y
# 677   2013.05.08.a  2013.0    M           Y
# 685   2013.04.13.a  2013.0    M           Y
# 696     2013.03.12  2013.0    M           Y
# ...            ...     ...  ...         ...
# 4321    1954.10.07  1954.0    M           Y
# 4326    1954.09.15  1954.0    M           Y
# 4327    1954.09.04  1954.0    M           Y
# 4332    1954.07.28  1954.0    M           Y
# 4334    1954.07.15  1954.0    M           Y
# 4337  1954.07.02.R  1954.0    M           Y
# 4341    1954.06.00  1954.0    M           Y
# 4342  1954.05.26.R  1954.0    M           Y
# 4346    1954.02.27  1954.0    M           Y
# 4351  1954.00.00.e  1954.0    M           Y
# 4353  1954.00.00.c  1954.0    M           Y
# 4363    1953.09.27  1953.0    M           Y
# 4370    1953.07.26  1953.0    M           Y
# 4385  1953.03.00.a  1953.0    M           Y
# 4392  1953.00.00.b  1953.0    M           Y
# 4398    1952.08.03  1952.0    M           Y
# 4399    1952.12.07  1952.0    M           Y
# 4400    1952.12.03  1952.0    M           Y
# 4407  1952.07.27.a  1952.0    M           Y
# 4418  1952.00.00.e  1952.0    M           Y
# 4420  1952.00.00.c  1952.0    M           Y
# 4421  1952.00.00.b  1952.0    M           Y
# 4422  1952.00.00.a  1952.0    M           Y
# 4423    1951.12.21  1951.0    M           Y
# 4426    1951.12.06  1951.0    M           Y
# 4430  1951.11.23.R  1951.0    M           Y
# 4431    1951.10.22  1951.0    M           Y
# 4435  1951.09.02-R  1951.0    M           Y
# 4442    1951.06.25  1951.0    M           Y
# 4452    1951.01.21  1951.0    M           Y
#
# [489 rows x 4 columns]

# %%
var8 = (tiburon[["Fatal (Y/N)","Sex "]].agg([pandas.Series.mean,pandas.Series.std])

#tiburon = var8
        
#tiburon
# Out:
#   File "<ipython-input-1468-b63d724790c1>", line 5
#     #tiburon
#             ^
# SyntaxError: unexpected EOF while parsing
