# %%
import pandas as pd
import os

# %%
data = pd.read_csv('attacks.csv', encoding='latin-1')
data
# Out:
#         Case Number                  Date    Year          Type       Country  \
# 0        2018.06.25           25-Jun-2018  2018.0       Boating           USA
# 1        2018.06.18           18-Jun-2018  2018.0    Unprovoked           USA
# 2        2018.06.09           09-Jun-2018  2018.0       Invalid           USA
# 3        2018.06.08           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4        2018.06.04           04-Jun-2018  2018.0      Provoked        MEXICO
# 5      2018.06.03.b           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6      2018.06.03.a           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7        2018.05.27           27-May-2018  2018.0    Unprovoked           USA
# 8      2018.05.26.b           26-May-2018  2018.0    Unprovoked           USA
# 9      2018.05.26.a           26-May-2018  2018.0    Unprovoked           USA
# 10       2018.05.24           24-May-2018  2018.0      Provoked     AUSTRALIA
# ...

# %%
#Después de haber importado la base de datos, lo primero que hago es buscar información 
#sobre el dataframe (¿Qué columnas la componen?, ¿Cuántos datos continenen?,etc. )

# %%
#Cuantas líneas y columnas
data.shape
# Out:
# (25723, 24)

# %%
#El nombre de las columnas
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
data.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
#HIPÓTESIS:

#Después de haber observado el dataframe y el tipo de información que la integra, 
#considero que sería interesante realizar mi trabajo con respecto a la siguiente hipótesis:

#A ciertas horas del día (time), los ataques tienen consecuencias fatales (fatal).

# %%
data["Time"].value_counts()
# Out:
# Afternoon                      187
# 11h00                          128
# Morning                        121
# 12h00                          109
# 15h00                          108
# 16h00                          101
# 14h00                           97
# 16h30                           74
# 17h00                           73
# 14h30                           73
# 13h00                           72
# 17h30                           70
# 18h00                           69
# 15h30                           66
# Night                           62
# 11h30                           61
# 13h30                           60
# 10h00                           59
# 09h00                           50
# 10h30                           49
# 12h30                           36
# Late afternoon                  35
# 09h30                           35
# Evening                         34
# 07h30                           33
# 18h30                           32
# 08h00                           31
# ...

# %%
data['Time'].describe()
# Out:
# count          2948
# unique          366
# top       Afternoon
# freq            187
# Name: Time, dtype: object

# %%
data["Fatal (Y/N)"].value_counts()
# Out:
# N          4293
# Y          1388
# UNKNOWN      71
#  N            7
# N             1
# 2017          1
# y             1
# M             1
# Name: Fatal (Y/N), dtype: int64

# %%
data['Fatal (Y/N)'].describe()
# Out:
# count     5763
# unique       8
# top          N
# freq      4293
# Name: Fatal (Y/N), dtype: object

# %%
data["Case Number"].value_counts()
# Out:
# 0                 2400
# 1980.07.00           2
# 1923.00.00.a         2
# 1920.00.00.b         2
# 1962.06.11.b         2
# 2013.10.05           2
# 1990.05.10           2
# 1907.10.16.R         2
# 2009.12.18           2
# 2014.08.02           2
# 1966.12.26           2
# 1983.06.15           2
# 1913.08.27.R         2
# 2005.04.06           2
# 2006.09.02           2
# 1915.07.06.a.R       2
# 2012.09.02.b         2
# 1968.12.02           1
# 2013.06.25.b         1
# 1914.09.26.R         1
# 1986.10.17           1
# 1988.04.24           1
# 1971.04.11           1
# 1987.04.01           1
# 1910.00.00.b         1
# 1993.10.26           1
# 1998.08.30           1
# 2013.03.21           1
# 2009.10.29.R         1
# 2013.12.05           1
#                   ...
# 1957.04.07.a         1
# 1921.07.21           1
# 1950.03.01           1
# 2006.05.28           1
# 1954.00.00.d         1
# 1953.00.00.a         1
# 1968.02.04           1
# 1928.04.06           1
# 2015.07.19           1
# ...

# %%
data['Case Number'].describe()
# Out:
# count     8702
# unique    6287
# top          0
# freq      2400
# Name: Case Number, dtype: object

# %%
#En primer lugar, voy a eliminar columnas que no tienen ninguna relación con lo que quiero valorar 
#y que están vacías de información.
data1 = data.drop(columns="Unnamed: 22")
data2 = data1.drop(columns="Unnamed: 23")
# Out:
#         Case Number                  Date    Year          Type       Country  \
# 0        2018.06.25           25-Jun-2018  2018.0       Boating           USA
# 1        2018.06.18           18-Jun-2018  2018.0    Unprovoked           USA
# 2        2018.06.09           09-Jun-2018  2018.0       Invalid           USA
# 3        2018.06.08           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4        2018.06.04           04-Jun-2018  2018.0      Provoked        MEXICO
# 5      2018.06.03.b           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6      2018.06.03.a           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7        2018.05.27           27-May-2018  2018.0    Unprovoked           USA
# 8      2018.05.26.b           26-May-2018  2018.0    Unprovoked           USA
# 9      2018.05.26.a           26-May-2018  2018.0    Unprovoked           USA
# 10       2018.05.24           24-May-2018  2018.0      Provoked     AUSTRALIA
# ...

# %%
#COLUMNA FATAL

data3 = data2.replace(['y', ' N','N ','M','2017',],['Y','N','N','N','UNKNOWN'])
data3["Fatal (Y/N)"].value_counts()

#COLUMNA TIME
#Aquí he considerado que la noche forma parte de la tarde, ya que me parecía mucho más sencillo repartir las horas 
#entre las mañanas y las tardes (AM/PM).
#data5 = data4.replace(['00h00','00h30','01h00','01h30','02h00','02h30','03h00','03h30','04h00','04h30','05h00','05h30','06h00','06h30','07h00','07h30','08h00','08h30','09h00','09h30','10h00','10h30','11h00','11h30','Early morning','AM'],['Morning','Morning','Morning','Morning','Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning', 'Morning'])
#data6 = data5.replace(['12h00','12h30','13h00','13h30','14h00','14h30','15h00','15h30','16h00','16h30','17h00','17h30','18h00','18h30','19h00','19h30','20h00','20h30','21h00','21h30','22h00','22h30','23h00','23h30','Late afternoon','Night','Evening','Midday','"Night"','PM'],['Afternoon','Afternoon','Afternoon','Afternoon','Afternoon','Afternoon','Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon'])
#data7 = data6.replace(['12h00','12h30','13h00','13h30','14h00','14h30','15h00','15h30','16h00','16h30','17h00','17h30','18h00','18h30','19h00','19h30','20h00','20h30','21h00','21h30','22h00','22h30','23h00','23h30','Late afternoon','Night','Midday','"Night"'],['Afternoon','Afternoon','Afternoon','Afternoon','Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon', 'Afternoon'])

#data6['Time'].value_counts()
# Out:
# N          4302
# Y          1389
# UNKNOWN      72
# Name: Fatal (Y/N), dtype: int64

# %%
#COLUMNA TIME
