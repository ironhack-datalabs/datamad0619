# %%
import pandas as pd
import os
from re import sub

# %%
data = pd.read_csv('attacks.csv', encoding='latin-1')
data
# Out:
#         Case Number                  Date    Year          Type       Country  \
# 0        2018.06.25           25-Jun-2018  2018.0       Boating           USA
# 1        2018.06.18           18-Jun-2018  2018.0    Unprovoked           USA
# 2        2018.06.09           09-Jun-2018  2018.0       Invalid           USA
# 3        2018.06.08           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4        2018.06.04           04-Jun-2018  2018.0      Provoked        MEXICO
# 5      2018.06.03.b           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6      2018.06.03.a           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7        2018.05.27           27-May-2018  2018.0    Unprovoked           USA
# 8      2018.05.26.b           26-May-2018  2018.0    Unprovoked           USA
# 9      2018.05.26.a           26-May-2018  2018.0    Unprovoked           USA
# 10       2018.05.24           24-May-2018  2018.0      Provoked     AUSTRALIA
# ...

# %%
#PRIMER VISTAZO A LOS DATOS
#Después de haber importado la base de datos, lo primero que hago es buscar información 
#sobre el dataframe (¿Qué columnas la componen?, ¿Cuántos datos continenen?, 
#¿Hay alguna columna que pueda borrar?, etc.)

# %%
#Cuantas líneas y columnas
tamaño = data.shape

# %%
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
tipo_datos = data.dtypes
tipo_datos.head()
# Out:
# Case Number     object
# Date            object
# Year           float64
# Type            object
# Country         object
# dtype: object

# %%
#Voy a borrar estas columnas que tienen información incomprensible

#data["Unnamed: 22"].value_counts()
#data["Unnamed: 23"].value_counts()
#data["Case Number.1"].value_counts()
#data["Case Number.2"].value_counts()
#data['original order'].value_counts()

data1 = data.drop(columns="Unnamed: 22")
data2 = data1.drop(columns="Unnamed: 23")
data3 = data2.drop(columns="Case Number.1")
data4 = data3.drop(columns="Case Number.2")
data5 = data4.drop(columns="original order")
data5.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
#HIPÓTESIS:

#Después de haber observado el dataframe y el tipo de información que la integra, 
#considero que sería interesante realizar mi trabajo con respecto a la siguiente hipótesis:

#En los últimos años el número de ataques de tiburón tienen consecuencias menos importantes para sus víctimas. 
#Compararé los años 2000-2010 y los años 1950-1960, observando el número total de ataques así como su proporción.
#También quiero observar si hay más mujeres víctimas en los 2000 que en los años 50, debido a que la emancipación 
#de las mujeres ha hecho que trabajen más fuera de casa y que tengan más tiempo de ocio (en general y también en el mar).

# %%
#Voy a empezar a trabajar con la columna Year:

# %%
#YEAR
d1 = data["Year"].value_counts()
d1
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
# 0.0       125
# 2008.0    122
# 2013.0    122
# 2009.0    120
# 2012.0    117
# 2007.0    112
# 2006.0    103
# 2005.0    103
# 2010.0    101
# 2000.0     97
# 1959.0     93
# 1960.0     93
# 2003.0     92
# 2004.0     92
# 2001.0     92
# 2002.0     88
# 1962.0     86
# 1961.0     78
# 1995.0     76
# 1999.0     66
# 1964.0     66
# 1998.0     65
# 1963.0     61
# 1996.0     61
# 1966.0     58
#          ...
# 1784.0      1
# 1617.0      1
# 1764.0      1
# 1721.0      1
# 1792.0      1
# 1834.0      1
# 1841.0      1
# 1595.0      1
# 1755.0      1
# 1738.0      1
# 1807.0      1
# 1723.0      1
# 1804.0      1
# 1780.0      1
# 1801.0      1
# 1767.0      1
# 1815.0      1
# 1822.0      1
# 1818.0      1
# 1783.0      1
# 1797.0      1
# 1800.0      1
# 1771.0      1
# 1748.0      1
# 1555.0      1
# 1753.0      1
# 77.0        1
# 1785.0      1
# 1580.0      1
# 1543.0      1
# ...

# %%
# ¿Cómo se quita el .0?
#d1["Year"] = d1["Year"].replace({'.0': ''}, regex=True)

# %%
#Genero la función para modificar los objetos NaN por 0:
def clean_object(input_object):
    if input_object == NaN:
        return 0

# %%
#¿Es necesario convertir los registros de la columna year en int? ¿O se pueden quedar como int64?
#d2 = sub([0],"",d1)
#d3 = d2["Year"].map(clean_year).astype(float)
#d3.describe()

# %%
#FATAL
d2 = data["Fatal (Y/N)"].value_counts()
d2.head()
# Out:
# N          4293
# Y          1388
# UNKNOWN      71
#  N            7
# N             1
# Name: Fatal (Y/N), dtype: int64

# %%
data3 = data2.replace(['y', ' N','N ','M','2017',],['Y','N','N','N','UNKNOWN'])
data3["Fatal (Y/N)"].value_counts()
# Out:
# N          4302
# Y          1389
# UNKNOWN      72
# Name: Fatal (Y/N), dtype: int64

# %%
#SEX
d4 = data["Sex "].value_counts()
d4
# Out:
# M      5094
# F       637
# M         2
# N         2
# .         1
# lli       1
# Name: Sex , dtype: int64

# %%
data5 = data4.replace([' M', 'M ','N','.','lli',],['M','M','M','UNKNOWN','UNKNOWN'])
data5["Sex "].value_counts()
# Out:
# M          5098
# F           637
# UNKNOWN       2
# Name: Sex , dtype: int64
