# %% [markdown]
# # Cleaning sharks dataframe

# %% [markdown]
# Paso 1: importar dataframe y hacer una primera observación de los datos que la componen

# %%
import pandas as pd
import os
from re import sub
import numpy
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# En primer lugar, importo el dataframe con el que voy a trabajar para poder empezar a trabajar con los datos.

# %%
data = pd.read_csv('attacks.csv', encoding='latin-1')
data.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %% [markdown]
# Después de haber importado este dataframe, busco resolver algunas primeras dudas (¿Qué columnas la componen?, ¿Cuántos datos continenen?, ¿Cuántos nulos hay por columna?, etc.)

# %%
#Número de filas y columnas
data.shape
# Out:
# (25723, 24)

# %%
#Nombre de las columnas
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#tipo de datos
data.dtypes.head()
# Out:
# Case Number     object
# Date            object
# Year           float64
# Type            object
# Country         object
# dtype: object

# %%
#También me interesa saber cuantos nulos tengo en cada variable
data.isnull().sum().head()
# Out:
# Case Number    17021
# Date           19421
# Year           19423
# Type           19425
# Country        19471
# dtype: int64

# %% [markdown]
# Creo una copia de la base de datos original, para trabajar desde esa copia (tiburon):

# %%
tiburon = data
tiburon.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %% [markdown]
# HIPÓTESIS:
#
# Después de haber observado el DataFrame y el tipo de información que la integra, considero que sería interesante realizar mi trabajo con respecto a la siguiente hipótesis: En los últimos años el número de ataques de tiburón tienen consecuencias menos importantes para sus víctimas. Compararé los años 2000-2010 y los años 1950-1960, observando el número total de ataques fatales así como su proporción con respecto al total de ataques.
#
# También quiero observar si hay más mujeres víctimas en los años 2000 que en los años 1950 (aunque no pueda contrastar datos para demostrar una causalidad, me baso en una creencia personal: creo que la emancipación de las mujeres ha hecho que en los últimos años, ellas trabajen más fuera de casa y que tengan más tiempo de ocio (en general, y por ende también en el mar). Por lo que es posible que a día de hoy tengan más posibilidades de ser víctimas de ataques de tiburones (y ataques fatales), que en los años 1950. Aunque, por supuesto, esta causalidad no la podré estudiar debido a que no tengo datos.

# %% [markdown]
# Paso 2: Hacer la limpieza de datos

# %% [markdown]
# Aunque existen muchas maneras de limpiar datos, he decidido quedarme exclusivamente con la información que me permite realizar el trabajo en base a mi hipótesis. He tomado esta decisión ya que considero que la recogida de datos contiene muchos errores por lo que considero peligroso basarme en otras columnas que no sean aquellas que necesito para mi trabajo. Veremos hasta qué punto los resultados que voy a obtener son significativos, con respecto a la muestra con la que pueda operar.

# %%
#Elimino las columnas con las que voy a operar, creando la variable col_malas

col_malas = tiburon.drop(columns = ['Date','Type','Country','Area','Location','Activity','Name','Age','Injury','Time','Species ','Investigator or Source','pdf','href formula','href','Case Number.1','Case Number.2','original order','Unnamed: 22','Unnamed: 23'], axis=1)
tiburon = col_malas
tiburon
# Out:
#         Case Number    Year Sex  Fatal (Y/N)
# 0        2018.06.25  2018.0    F           N
# 1        2018.06.18  2018.0    F           N
# 2        2018.06.09  2018.0    M           N
# 3        2018.06.08  2018.0    M           N
# 4        2018.06.04  2018.0    M           N
# 5      2018.06.03.b  2018.0    M           N
# 6      2018.06.03.a  2018.0    M           Y
# 7        2018.05.27  2018.0    M           N
# 8      2018.05.26.b  2018.0    M           N
# 9      2018.05.26.a  2018.0    M           N
# 10       2018.05.24  2018.0    M           N
# 11       2018.05.21  2018.0    M           N
# 12     2018.05.13.b  2018.0    M           N
# 13     2018.05.13.a  2018.0    M           N
# 14       2018.05.00  2018.0    F           N
# 15       2018.05.12  2018.0    M           N
# 16       2018.05.09  2018.0    M           N
# 17     2018.04.30.R  2018.0    M           N
# 18     2018.04.28.b  2018.0    M           N
# 19     2018.04.28.a  2018.0    M           N
# ...

# %% [markdown]
# Para entrenarme a crear funciones, y sabiendo que voy a tener que limpiar muchos datos, he decidido crear una función para conocer número de valores de todas las columnas:

# %%
def cls_counts(df):
    for col in df.columns:
        print("---%s---" %col)
        print(df[col].value_counts())

# %%
#Pruebo mi función:
cls_counts(tiburon)
# Out:
# ---Case Number---
# 0                 2400
# 2014.08.02           2
# 2012.09.02.b         2
# 1962.06.11.b         2
# 2006.09.02           2
# 2005.04.06           2
# 1907.10.16.R         2
# 2009.12.18           2
# 1913.08.27.R         2
# 1923.00.00.a         2
# 2013.10.05           2
# 1980.07.00           2
# 1915.07.06.a.R       2
# 1983.06.15           2
# 1966.12.26           2
# 1920.00.00.b         2
# 1990.05.10           2
# 1945.02.05           1
# 1996.10.28.a         1
# 2016.12.06           1
# 2016.07.23.a         1
# ND-0119              1
# 2015.07.03           1
# 1910.05.16.R         1
# 2013.10.28           1
# 2009.07.11.a         1
# 2015.06.27.b         1
# 2008.04.27           1
# 1961.02.17.b         1
# 1988.06.01           1
#                   ...
# 1899.05.28           1
# 1930.08.31           1
# 1999.08.26           1
# 2016.10.01           1
# 1895.00.00.b         1
# 1972.09.04           1
# 1868.01.04.R         1
# 1998.08.15           1
# ...

# %% [markdown]
# Ahora voy a centrarme en limpiar por separado aquellas columnas que componen mi nueva tabla.

# %% [markdown]
# A) Fila Case Number

# %% [markdown]
# En primer lugar, quiero eliminar las filas duplicadas en la columna Case Number, ya que cada fila debería tener un valor diferente: vemos que cada registro está compuesto de la fecha AAAA-MM-DD y de letras en los casos en los que ha habido más de un ataque en el día. No podemos tener la certeza de que quitando duplicados tengamos el número total real de ataques, pero de ningún otro modo podríamos tener esa certeza.

# %%
#Eliminamos los registros duplicados si los hubiese
var1 = tiburon.drop_duplicates(subset=['Case Number'], keep='first')
tiburon['Case Number'] = var1
tiburon.head()
# Out:
#   Case Number    Year Sex  Fatal (Y/N)
# 0  2018.06.25  2018.0    F           N
# 1  2018.06.18  2018.0    F           N
# 2  2018.06.09  2018.0    M           N
# 3  2018.06.08  2018.0    M           N
# 4  2018.06.04  2018.0    M           N

# %% [markdown]
# Ahora voy a cambiar los registros nulos por 0:

# %%
var2 = tiburon.dropna(how = 'any')
tiburon = var2
tiburon.head()
# Out:
#   Case Number    Year Sex  Fatal (Y/N)
# 0  2018.06.25  2018.0    F           N
# 1  2018.06.18  2018.0    F           N
# 2  2018.06.09  2018.0    M           N
# 3  2018.06.08  2018.0    M           N
# 4  2018.06.04  2018.0    M           N

# %%
var3 = tiburon.drop([0],axis=0)

# %%
#Ahora voy a trabajar con la columna Year:

# %%
#YEAR
tiburon["Year"].value_counts()

#Observo que los registros son float y que también hay valores inverosímiles.
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
# 0.0       125
# 2008.0    122
# 2013.0    122
# 2009.0    120
# 2012.0    117
# 2007.0    112
# 2006.0    103
# 2005.0    103
# 2010.0    101
# 2000.0     97
# 1959.0     93
# 1960.0     93
# 2003.0     92
# 2004.0     92
# 2001.0     92
# 2002.0     88
# 1962.0     86
# 1961.0     78
# 1995.0     76
# 1999.0     66
# 1964.0     66
# 1998.0     65
# 1963.0     61
# 1996.0     61
# 1966.0     58
#          ...
# 1784.0      1
# 1617.0      1
# 1764.0      1
# 1721.0      1
# 1792.0      1
# 1834.0      1
# 1841.0      1
# 1595.0      1
# 1755.0      1
# 1738.0      1
# 1807.0      1
# 1723.0      1
# 1804.0      1
# 1780.0      1
# 1801.0      1
# 1767.0      1
# 1815.0      1
# 1822.0      1
# 1818.0      1
# 1783.0      1
# 1797.0      1
# 1800.0      1
# 1771.0      1
# 1748.0      1
# 1555.0      1
# 1753.0      1
# 77.0        1
# 1785.0      1
# 1580.0      1
# 1543.0      1
# ...

# %%
#Voy a ponerle otro valor a los valores nulos y así poder cambiar el tipo de los registros de Year:
#var4 = tiburon.fillna(0)
#tiburon = var4
#tiburon

# %%
#Voy a cambiar el tipo de los registros de la columna Year para quitar el ".0" 
#de todos los valores, ahora que ya no tengo valores nulos:

var5 = tiburon["Year"].astype("object")
tiburon["Year"]= var5
tiburon
# Out:
#         Case Number  Year Sex  Fatal (Y/N)
# 0        2018.06.25  2018    F           N
# 1        2018.06.18  2018    F           N
# 2        2018.06.09  2018    M           N
# 3        2018.06.08  2018    M           N
# 4        2018.06.04  2018    M           N
# 5      2018.06.03.b  2018    M           N
# 6      2018.06.03.a  2018    M           Y
# 7        2018.05.27  2018    M           N
# 8      2018.05.26.b  2018    M           N
# 9      2018.05.26.a  2018    M           N
# 10       2018.05.24  2018    M           N
# 11       2018.05.21  2018    M           N
# 12     2018.05.13.b  2018    M           N
# 13     2018.05.13.a  2018    M           N
# 14       2018.05.00  2018    F           N
# 15       2018.05.12  2018    M           N
# 16       2018.05.09  2018    M           N
# 17     2018.04.30.R  2018    M           N
# 18     2018.04.28.b  2018    M           N
# 19     2018.04.28.a  2018    M           N
# 20     2018.04.25.b  2018    M           N
# ...

# %%
#No soy capaz de quitar los 0
var6 = tiburon.dropna(how = 'any')
tiburon = var6
tiburon

#Esto está bien:
#var7 = tiburon.loc[~(tiburon!=0).any(axis=1)]
#tiburon = var7
#tiburon
# Out:
#        Case Number  Year Sex  Fatal (Y/N)
# 0       2018.06.25  2018    F           N
# 1       2018.06.18  2018    F           N
# 2       2018.06.09  2018    M           N
# 3       2018.06.08  2018    M           N
# 4       2018.06.04  2018    M           N
# 5     2018.06.03.b  2018    M           N
# 6     2018.06.03.a  2018    M           Y
# 7       2018.05.27  2018    M           N
# 8     2018.05.26.b  2018    M           N
# 9     2018.05.26.a  2018    M           N
# 10      2018.05.24  2018    M           N
# 11      2018.05.21  2018    M           N
# 12    2018.05.13.b  2018    M           N
# 13    2018.05.13.a  2018    M           N
# 14      2018.05.00  2018    F           N
# 15      2018.05.12  2018    M           N
# 16      2018.05.09  2018    M           N
# 17    2018.04.30.R  2018    M           N
# 18    2018.04.28.b  2018    M           N
# 19    2018.04.28.a  2018    M           N
# 20    2018.04.25.b  2018    M           N
# ...

# %%
#data5 = data4[data4["Year"]!= 0].copy()
#ass1 = data4[data4["Year"]!= 0].copy()
#ass1
#data4["Year"] = ass1
#cls_counts(data4)

# %%
#Voy a borrar los registros que no contienen año o un año realista (por ejemplo, 5, 77), 
#ya que va a resultar imposible trabajar con ello.
#Podría basarme en los registros como Case Number, pero tampoco tengo la certeza de que esos datos estén bien, y el 
#número de datos no es mi significativo para el total de registros que contiene la columna Years.

#data4["Year"].replace([0, 5, 77],[1, 1, 1])
#data5["Year"] = data4["Year"]

# %%
#data6 = data5.drop([1],axis=0)
#data6
#data5["Year"] = data5.set_index("Year",inplace=True)
#data4.drop["Year"]([1, 0, 5, 77], axis=0)
#data5.drop([1], axis=0,inplace=True)

#data = data.set_index("Area")
#data = data.drop("Ireland", axis=0)

# %%
#ass2 = data4["Year"].drop < 1000

#data4["Year"] = ass2
#data4.head()

#cols_no_nulls = raw_df2.columns[raw_df2.isnull().sum() < 1000]
#data_clean = data_clean[data_clean["Months"] & data_clean["Year"] != 0].copy()

# %%
#FATAL
#tiburon["Fatal (Y/N)"].value_counts()

# %%
#var7 = data2.replace(['y', ' N','N ','M','2017',],['Y','N','N','N','UNKNOWN'])
#No entiendo porqué Year vuelve a ser un float
var7 = tiburon.replace("[^N]", "N")
tiburon = var7
tiburon
#data3["Fatal (Y/N)"].value_counts()
# Out:
#        Case Number    Year Sex  Fatal (Y/N)
# 0       2018.06.25  2018.0    F           N
# 1       2018.06.18  2018.0    F           N
# 2       2018.06.09  2018.0    M           N
# 3       2018.06.08  2018.0    M           N
# 4       2018.06.04  2018.0    M           N
# 5     2018.06.03.b  2018.0    M           N
# 6     2018.06.03.a  2018.0    M           Y
# 7       2018.05.27  2018.0    M           N
# 8     2018.05.26.b  2018.0    M           N
# 9     2018.05.26.a  2018.0    M           N
# 10      2018.05.24  2018.0    M           N
# 11      2018.05.21  2018.0    M           N
# 12    2018.05.13.b  2018.0    M           N
# 13    2018.05.13.a  2018.0    M           N
# 14      2018.05.00  2018.0    F           N
# 15      2018.05.12  2018.0    M           N
# 16      2018.05.09  2018.0    M           N
# 17    2018.04.30.R  2018.0    M           N
# 18    2018.04.28.b  2018.0    M           N
# 19    2018.04.28.a  2018.0    M           N
# ...

# %%
#No consigo hacer que el número de casos sea count
#tiburon['Case Number'] = [len(x) for x in tiburon ['Case number Count']]
#tiburon

# %%
#Después de haber limpiado un poco mis columnas, voy a agrupar las columnas que me interesan
#de manera a poder estudiarlas con mayor profundidad

# %%
#df_pivot = tiburon.pivot_table(values = 'len()', columns = 'Year','Fatal (Y/N)', index = ['Sex '])
#tiburon = df_pivot
#tiburon

# %%
#var8 = tiburon.query('1950 <= Year <= 2010')
#tiburon = var8
#tiburon
#var9 = tiburon.query('2000 <= Year <= 2010')
#tiburon = var9
#tiburon

# %%
print(tiburon.loc[(tiburon["Year"] > 1950) & (tiburon["Fatal (Y/N)"] == "Y") & (tiburon["Sex "] == "M"),:])
# Out:
#        Case Number    Year Sex  Fatal (Y/N)
# 6     2018.06.03.a  2018.0    M           Y
# 64      2017.11.04  2017.0    M           Y
# 91    2017.09.03.b  2017.0    M           Y
# 144     2017.05.06  2017.0    M           Y
# 149   2017.04.29.a  2017.0    M           Y
# 174     2017.02.21  2017.0    M           Y
# 221     2016.09.06  2016.0    M           Y
# 271     2016.05.31  2016.0    M           Y
# 299     2016.03.10  2016.0    M           Y
# 325     2015.12.19  2015.0    M           Y
# 385     2015.07.25  2015.0    M           Y
# 425     2015.05.09  2015.0    M           Y
# 434     2015.04.12  2015.0    M           Y
# 440     2015.03.21  2015.0    M           Y
# 448     2015.02.09  2015.0    M           Y
# 464   2014.12.29.a  2014.0    M           Y
# 470     2014.12.15  2014.0    M           Y
# 473     2014.11.20  2014.0    M           Y
# 500     2014.09.09  2014.0    M           Y
# 571   2014.03.22.b  2014.0    M           Y
# ...

# %%
var8 = (tiburon[["Fatal (Y/N)","Sex "]].agg([pandas.Series.mean,pandas.Series.std])

#tiburon = var8
        
#tiburon
# Out:
#   File "<ipython-input-1468-b63d724790c1>", line 5
#     #tiburon
#             ^
# SyntaxError: unexpected EOF while parsing
