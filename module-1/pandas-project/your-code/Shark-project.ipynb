# %% [markdown]
# # Shark analysis project

# %% [markdown]
# On this project we are proceding to clean and analyse the dataset provided by Kaggle on shark attack incidents.

# %%
import pandas as pd

# %%
raw_df = pd.read_csv('GSAF5_uncleaned.csv', encoding='latin-1')
display(raw_df.head())
raw_df.shape
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# 0        NaN  Orlando Sentinel, 9/19/2016       2016.09.18.c-NSB.pdf
# 1        NaN  Orlando Sentinel, 9/19/2016   2016.09.18.b-Luciano.pdf
# 2        NaN  Orlando Sentinel, 9/19/2016       2016.09.18.a-NSB.pdf
# 3        NaN           The Age, 9/18/2016  2016.09.17-Angiolella.pdf
# 4  2 m shark           The Age, 9/16/2016  2016.09.16-BellsBeach.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.17
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0  2016.09.18.c           5993         NaN         NaN
# 1  2016.09.18.b           5992         NaN         NaN
# 2  2016.09.18.a           5991         NaN         NaN
# 3    2016.09.17           5990         NaN         NaN
# 4    2016.09.15           5989         NaN         NaN
#
# [5 rows x 24 columns]
# (5992, 24)

# %%
#Identify how many nulls you have for each variable
null_cols = raw_df.isnull().sum()

null_cols[null_cols > 0]
# Out:
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# href formula                 1
# href                         3
# Unnamed: 22               5991
# Unnamed: 23               5990
# dtype: int64

# %%
raw_df.columns

unnammed_cols = raw_df[["Unnamed: 22","Unnamed: 23"]]
unnammed_cols.head()

unnammed_cols.isnull().sum()

# We are going to delete these two columns as they aren't holding any useful data for the current analysis
# Out:
# Unnamed: 22    5991
# Unnamed: 23    5990
# dtype: int64

# %%
unnammed_cols = raw_df.drop(columns=["Unnamed: 22","Unnamed: 23"])
raw_df2 = unnammed_cols
raw_df2.head()
# We have deleted those columns
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#   Fatal (Y/N)   Time   Species        Investigator or Source  \
# 0           N  13h00        NaN  Orlando Sentinel, 9/19/2016
# 1           N  11h00        NaN  Orlando Sentinel, 9/19/2016
# 2           N  10h43        NaN  Orlando Sentinel, 9/19/2016
# 3           N    NaN        NaN           The Age, 9/18/2016
# 4           N    NaN  2 m shark           The Age, 9/16/2016
#
#                          pdf  \
# 0       2016.09.18.c-NSB.pdf
# 1   2016.09.18.b-Luciano.pdf
# 2       2016.09.18.a-NSB.pdf
# 3  2016.09.17-Angiolella.pdf
# 4  2016.09.16-BellsBeach.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.17
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
#
#   Case Number.2 original order
# 0  2016.09.18.c           5993
# 1  2016.09.18.b           5992
# 2  2016.09.18.a           5991
# 3    2016.09.17           5990
# 4    2016.09.15           5989
#
# [5 rows x 22 columns]

# %%
#raw_df2["Time"]
#Variable Time is not homogenized 

raw_df2.dtypes
#Let's tranform Age, Date (?), o concatenar date con Year -- También TIME 
###OJO CON INJURY

#raw_df2.replace({'Fatal (Y/N)': {'Y': True, 'N': False}})
#raw_df2["Fatal (Y/N)"].value_counts().head()

#raw_df2.replace()
#[^x]
#df.replace(replacements, regex=True, inplace=True)

#raw_df2.dtypes
#df.at['C', 'x'] = 10"""
# Out:
# N          4315
# Y          1552
# UNKNOWN      94
#  N            8
# #VALUE!       1
# Name: Fatal (Y/N), dtype: int64

# %%
import numpy as np
import re

#replace({"10-Jan": "1-10", "Nov-50": "11-50"})



#raw_df2['Fatal (Y/N)'].replace(lambda x : if  x != "Y" | "N", np.nan, inplace=True)




raw_df2['Fatal (Y/N)'].replace(['UNKNOWN', '#VALUE!'], np.nan, inplace=True)
raw_df2.replace("[^N]", "N", inplace=True)



#raw_df2['Fatal (Y/N)'].replace(['F', ' N', "N ", "n"], "N", inplace=True)



raw_df2['Fatal (Y/N)'].value_counts()
# Out:
# N    4326
# Y    1552
# Name: Fatal (Y/N), dtype: int64

# %%
raw_df2["Type"].value_counts()
# Out:
# Unprovoked      4386
# Provoked         557
# Invalid          519
# Sea Disaster     220
# Boat             200
# Boating          110
# Name: Type, dtype: int64

# %%
raw_df2.columns
raw
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order'],
#       dtype='object')

# %%
#BUENO#raw_df2[["Case Number","Date", "Case Number.1", "Case Number.2"]]

#raw_df2[["Case Number","Date", "Year", "Time"]]
#raw_df2["Date"].value_counts()

#datetime.datetime.strptime("11/12/98","%d/%m/%y")


## Si sacamos el año de la fecha date, como valor numérico, tendremos escala temporal anual.
## Para los meses, podemos repartir en función de si lo tienen o no y ahí valorar si nos interesa hacer un análisis de eso
import re
#Extrae el formato fecha 00.00.00

raw_df2["months"] = raw_df2["Case Number"].str.findall('\d+.\d+.\d+')
#raw_df2["Case Number"].replace(pattern, regex=True)
#raw_df2["Case Number"].astype(date)
#raw_df2.columns
#raw_df2["cleaned_dates"].value_counts()
q = raw_df2["cleaned_dates"]
#q = raw_df2["cleaned_dates"].replace(r'[/-]',',',regex=True)
q[q.isnull()] = 0
# Out:
# /home/slimbook/.local/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#raw_df2["Case Number"].apply(raw_df2.to_datetime("Case Number"))
#\.\d\d\d\d\.()



#int(s) for s in str.split() if s.isdigit()] ==> [23, 11, 2] 
raw_df2["Date"].value_counts()
# Out:
# 1957                            11
# 1942                             9
# 1956                             8
# 1950                             7
# 1941                             7
# 1958                             7
# 1949                             6
# No date                          6
# Oct-60                           5
# 1959                             5
# 12-Apr-01                        5
# 1954                             5
# 28-Jul-95                        5
# 1955                             5
# No date, Before 1963             5
# 1970s                            5
# 05-Oct-03                        5
# Aug-56                           5
# 1940                             5
# 27-Dec-08                        4
# 1961                             4
# 1945                             4
# 1938                             4
# 1960                             4
# 1995                             4
# 1890                             4
# 1952                             4
# 1960s                            4
# 14-Jun-12                        4
# Before 1958                      4
#                                 ..
#  11-Jan-1896                     1
# Reported 21-Feb-1835             1
# 1980                             1
# 30-Dec-1890                      1
# Circa 1872                       1
# 19-Jul-71                        1
# Aug-66                           1
# 20-Jul-81                        1
# Reported 06-Mar-1886             1
# 28-Jan-16                        1
# 24-Mar-02                        1
# Reported 04-Jun-1876             1
# 16-Aug--2011                     1
# Reported 20-Feb-1936             1
# 06-Jun-89                        1
# Circa 1958                       1
# 11-Aug-02                        1
# Mid Jul-1985 or mid Jul-1986     1
# 24-Jun-58                        1
# 17-Mar-84                        1
# 21-May-06                        1
# 04-Apr-1893                      1
# 07-Apr-05                        1
# 17-Aug-10                        1
# 18-Oct-98                        1
# 25-Sep-71                        1
# 20-May-75                        1
# 19-Mar-67                        1
# 08-Jul-12                        1
# 10-Jan-66                        1
# Name: Date, Length: 5128, dtype: int64

# %%
raw_df2["Date"]

def findMonth (m):
    months = {
        "Jan":1, "Feb":2, "Mar":3, "Apr":4, "May":5, "Jun":6, "Jul":7, "Aug":8, "Sep":9, "Oct":10, "Nov":11, "Dec":12
    }
    for month, numero in months.items(): 
        if month in m: 
            return numero
    return None
    
raw_df2["Months"] = raw_df2["Date"].apply(findMonth)
#raw_df2["Months"].value_counts()

raw_df2["Months"] = raw_df2["Months"].fillna(0).astype("int64")
#raw_df2["Months"] = raw_df2["Months"].astype("int64")

raw_df2["Months"].dtype

#raw_df2[["Case Number", "Months", "Year"]].head()
# Out:
# dtype('int64')

# %%
"""month = {
        "Jan":1, "Feb":2, "Mar":3, "Apr":4, "May":5, "Jun":6, "Jul":7, "Aug":8, "Sep":9, "Oct":10, "Nov":11, "Dec":12
    }
month.get('Jan', None)
    """
# Out:
# 'month = {\n        "Jan":1, "Feb":2, "Mar":3, "Apr":4, "May":5, "Jun":6, "Jul":7, "Aug":8, "Sep":9, "Oct":10, "Nov":11, "Dec":12\n    }\nmonth.get(\'Jan\', None)\n    '

# %%
#raw_df2.columns
#raw_df2["Year"].value_counts()
# Out:
# 2015    139
# 2011    128
# 2014    125
# 0       124
# 2013    122
# 2008    121
# 2009    120
# 2012    117
# 2007    112
# 2006    103
# 2016    103
# 2005    103
# 2010    101
# 2000     97
# 1959     93
# 1960     93
# 2001     92
# 2004     92
# 2003     92
# 2002     88
# 1962     86
# 1961     78
# 1995     76
# 1964     66
# 1998     65
# 1999     65
# 1996     61
# 1963     61
# 1966     58
# 1997     57
#        ...
# 1785      1
# 1834      1
# 1791      1
# 1733      1
# 1721      1
# 1637      1
# 1617      1
# 77        1
# 5         1
# 1703      1
# 1755      1
# 1767      1
# 1771      1
# 1779      1
# 1787      1
# 1803      1
# 1749      1
# 1807      1
# 1811      1
# 1819      1
# 1805      1
# 1831      1
# 1555      1
# 1738      1
# 1859      1
# 1742      1
# 1758      1
# 1818      1
# 1822      1
# 1595      1
# Name: Year, Length: 232, dtype: int64

# %%
"""#def extractYear(y):
q = raw_df2["Months"].replace("[/-][\s*\d\d\d\d][\d\d\d\d\s*\d\d\d\d]",",", regex=True)
q[q.isnull()] = 0

data_hypothesis_clean_dates = data_hypothesis[data_hypothesis['Month'] != '123asdasdkfkfk'].copy()
display(data_hypothesis_clean_dates)
q[q.str.find(',') > 0] = [mean(map(lambda x: int(x),e.split(','))) for e in x]
#display(q[q.str.find(',') > 0])

#raw_df2["Months"]."""

raw_df2.shape
6000*0.1
# Out:
# 600.0

# %%
raw_df2.head()
raw_df2.columns
raw_df2[["Case Number", "Months", "Year"]]
# Out:
#        Case Number  Months  Year
# 0     2016.09.18.c       9  2016
# 1     2016.09.18.b       9  2016
# 2     2016.09.18.a       9  2016
# 3       2016.09.17       9  2016
# 4       2016.09.15       9  2016
# 5     2016.09.15.R       9  2016
# 6       2016.09.11       9  2016
# 7       2016.09.07       9  2016
# 8       2016.09.06       9  2016
# 9     2016.09.05.b       9  2016
# 10    2016.09.05.a       9  2016
# 11      2016.09.04       9  2016
# 12      2016.09.01       9  2016
# 13    2016.08.29.b       8  2016
# 14    2016.08.29.a       8  2016
# 15      2016.08.27       8  2016
# 16      2016.08.25       8  2016
# 17      2016.08.07       8  2016
# 18      2016.08.06       8  2016
# 19      2016.08.04       8  2016
# 20      2016.07.29       7  2016
# 21    2016.07.28.R       7  2016
# 22      2016.07.28       7  2016
# 23      2016.07.27       7  2016
# 24      2016.07.26       7  2016
# 25      2016.07.24       7  2016
# 26    2016.07.23.b       7  2016
# 27    2016.07.23.a       7  2016
# 28      2016.07.20       7  2016
# 29      2016.07.17       7  2016
# ...            ...     ...   ...
# 5962       ND.0031       0     0
# 5963       ND.0030       0     0
# 5964       ND.0028       0     0
# 5965       ND.0027       0     0
# 5966       ND.0026       0     0
# 5967       ND.0025       0     0
# 5968       ND.0024       0     0
# 5969       ND.0023       0     0
# 5970       ND.0022       0     0
# 5971       ND.0021       0     0
# 5972       ND.0020       0     0
# 5973       ND.0019       0     0
# 5974       ND.0018       0     0
# 5975       ND.0017       0     0
# 5976       ND.0016       0     0
# 5977       ND.0015       0     0
# 5978       ND.0014       7     0
# 5979       ND.0013       7     0
# 5980       ND.0012       7     0
# 5981       ND.0011       0     0
# 5982       ND.0010       0     0
# 5983       ND.0009       0     0
# 5984       ND.0008       0     0
# 5985       ND.0007       0     0
# 5986       ND.0006       0     0
# 5987       ND.0005       0     0
# 5988       ND.0004       0     0
# 5989       ND.0003       0     0
# 5990       ND.0002       0     0
# 5991       ND.0001       0     0
#
# [5992 rows x 3 columns]

# %%
cols_no_nulls = raw_df2.columns[data.isnull().sum() < 1000]
raw_df2.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-207-3418534c3820> in <module>
# ----> 1 cols_no_nulls = raw_df2.columns[data.isnull().sum() < 1000]
#       2 raw_df2.shape
#
# NameError: name 'data' is not defined

# %%
data_clean = raw_df2[cols_no_nulls]

# %%
data_clean.shape
