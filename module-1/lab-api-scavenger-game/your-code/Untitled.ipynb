# %%
import json
import requests



with open ("../token.txt", "r") as myfile:
    acceso = myfile.readlines()
    
key = acceso[0]
user = "roskor97"


repo = 'ironhack-datalabs/madrid-oct-2018'
get_forks = 'http://api.github.com/repos/'+ repo +'/forks'

res_fork = requests.get(get_forks, auth=(user, key))
results_fork = res_fork.json()

#languages = set()

#for i in range(len(results_fork)):
    #languages.add(results_fork[i]['language'])

#print(languages)
print(res_fork.json())
# Out:
# [{'id': 193946632, 'node_id': 'MDEwOlJlcG9zaXRvcnkxOTM5NDY2MzI=', 'name': 'mad-oct-2018', 'full_name': 'aiborra11/mad-oct-2018', 'private': False, 'owner': {'login': 'aiborra11', 'id': 48259489, 'node_id': 'MDQ6VXNlcjQ4MjU5NDg5', 'avatar_url': 'https://avatars0.githubusercontent.com/u/48259489?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/aiborra11', 'html_url': 'https://github.com/aiborra11', 'followers_url': 'https://api.github.com/users/aiborra11/followers', 'following_url': 'https://api.github.com/users/aiborra11/following{/other_user}', 'gists_url': 'https://api.github.com/users/aiborra11/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/aiborra11/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/aiborra11/subscriptions', 'organizations_url': 'https://api.github.com/users/aiborra11/orgs', 'repos_url': 'https://api.github.com/users/aiborra11/repos', 'events_url': 'https://api.github.com/users/aiborra11/events{/privacy}', 'received_events_url': 'https://api.github.com/users/aiborra11/received_events', 'type': 'User', 'site_admin': False}, 'html_url': 'https://github.com/aiborra11/mad-oct-2018', 'description': 'Student labs for Ironhack data analytics bootcamp', 'fork': True, 'url': 'https://api.github.com/repos/aiborra11/mad-oct-2018', 'forks_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/forks', 'keys_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/teams', 'hooks_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/hooks', 'issue_events_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/issues/events{/number}', 'events_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/events', 'assignees_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/assignees{/user}', 'branches_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/branches{/branch}', 'tags_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/tags', 'blobs_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/languages', 'stargazers_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/stargazers', 'contributors_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/contributors', 'subscribers_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/subscribers', 'subscription_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/subscription', 'commits_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/contents/{+path}', 'compare_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/merges', 'archive_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/downloads', 'issues_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/issues{/number}', 'pulls_url': 'https://api.github.com/repos/aiborra11/mad-oct-2018/pulls{/number}', 'milestones_url': 'https://api.gi ...
