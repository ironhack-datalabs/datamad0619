# %%
import requests

# %%
with open ("Token.txt", "r") as myfile:
    acceso=myfile.readlines()
    
key=acceso[0]
user= 'CMFV'

# %%
repo2='ironhack-datalabs/scavenger'
get_files=requests.get("https://api.github.com/repos/{}".format(repo2))

res_files=requests.get(get_files, auth=(user, key))
result_files=res_files.json()
result_files
# Out:
# ---------------------------------------------------------------------------
# LocationParseError                        Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/requests/models.py in prepare_url(self, url, params)
#     378         try:
# --> 379             scheme, auth, host, port, path, query, fragment = parse_url(url)
#     380         except LocationParseError as e:
#
# /usr/local/lib/python3.7/site-packages/urllib3/util/url.py in parse_url(url)
#     233     if has_authority and uri_ref.authority is None:
# --> 234         raise LocationParseError(url)
#     235
#
# LocationParseError: Failed to parse: //<Response [200]>
#
# During handling of the above exception, another exception occurred:
#
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-3-29a507957bd4> in <module>
#       2 get_files=requests.get("https://api.github.com/repos/{}".format(repo2))
#       3
# ...
